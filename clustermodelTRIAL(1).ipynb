# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

def preprocess_city_data(file_path, city_name):
    df = pd.read_excel(file_path)
    df.dropna(inplace=True)

    time_column = 'l' if city_name == 'Chicago' else 'Time'
    df['Time'] = pd.to_datetime(df[time_column])

    df['Hour'] = df['Time'].dt.hour
    df['DayOfWeek'] = df['Time'].dt.dayofweek
    df['Month'] = df['Time'].dt.month
    df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

    for lag in range(1, 25):
        df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

    df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
    df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

    df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

    df.dropna(inplace=True)

    return df


cities_data = []
city_files = {
    'Chicago': 'City-Specific Data/Chicago.xlsx',
    'Los Angeles': 'City-Specific Data/Los Angeles.xlsx',
}

for city, file_path in city_files.items():
    city_data = preprocess_city_data(file_path, city)
    city_data['City'] = city
    cities_data.append(city_data)


df_all = pd.concat(cities_data, ignore_index=True)


features = df_all[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
                   'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
                   'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
                   'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
                   'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
                   'Temp_RollingMean_24', 'Temp_RollingStd_24',
                   'Temp_Humidity_Interaction']].values
energy_demand = df_all['EnergyDemand'].values.reshape(-1, 1)
dates = df_all['Time'].values


scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=False)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

    # Training the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Making predictions
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate metrics
    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    # Store results
    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)


result_df.to_csv('all_cities_predictions.csv', index=False)


average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")


plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 0.0011 - val_loss: 2.8879e-05
# Epoch 2/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 4.3139e-05 - val_loss: 1.8553e-05
# Epoch 3/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.0787e-05 - val_loss: 1.4620e-05
# Epoch 4/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 2.5106e-05 - val_loss: 1.5534e-05
# Epoch 5/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.1399e-05 - val_loss: 1.3496e-05
# Epoch 6/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 1.8764e-05 - val_loss: 1.1231e-05
# Epoch 7/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 1.7773e-05 - val_loss: 1.8397e-05
# Epoch 8/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 1.6775e-05 - val_loss: 1.0328e-05
# Epoch 9/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 1.5578e-05 - val_loss: 1.1215e-05
# Epoch 10/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 1.5268e-05 - val_loss: 1.1399e-05
# Epoch 11/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - loss: 1.4542e-05 - val_loss: 1.4471e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - loss: 3.6420e-04 - val_loss: 2.6423e-05
# Epoch 2/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 81s 36ms/step - loss: 9.3479e-05 - val_loss: 2.5866e-05
# Epoch 3/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 7.1911e-05 - val_loss: 2.2763e-05
# Epoch 4/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 3.8454e-05 - val_loss: 1.9896e-05
# Epoch 5/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.7566e-05 - val_loss: 1.4652e-05
# Epoch 6/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.7566e-05 - val_loss: 1.3606e-05
# Epoch 7/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.5906e-05 - val_loss: 1.6445e-05
# Epoch 8/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 3.3549e-05 - val_loss: 1.4665e-05
# Epoch 9/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 3.1751e-05 - val_loss: 1.2534e-05
# Epoch 10/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 4.2130e-05 - val_loss: 1.1471e-05
# Epoch 11/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 2.5975e-05 - val_loss: 1.2931e-05
# Epoch 12/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 2.6152e-05 - val_loss: 1.5415e-05
# Epoch 13/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 3.1153e-05 - val_loss: 1.2246e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 0.0018 - val_loss: 2.8361e-05
# Epoch 2/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 5.0296e-05 - val_loss: 2.9628e-05
# Epoch 3/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 7.1276e-05 - val_loss: 2.1992e-05
# Epoch 4/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - loss: 4.4279e-05 - val_loss: 2.1397e-05
# Epoch 5/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 7.2514e-05 - val_loss: 1.3679e-05
# Epoch 6/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - loss: 3.6802e-05 - val_loss: 4.0724e-05
# Epoch 7/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 4.3535e-05 - val_loss: 1.5318e-05
# Epoch 8/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 6.1956e-05 - val_loss: 1.7195e-05
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 4.0777e-04 - val_loss: 3.5380e-05
# Epoch 2/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 6.4762e-05 - val_loss: 2.4118e-05
# Epoch 3/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 6.7267e-05 - val_loss: 2.0157e-05
# Epoch 4/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 7.6620e-05 - val_loss: 1.6251e-05
# Epoch 5/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 4.3089e-05 - val_loss: 1.8580e-05
# Epoch 6/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 6.0024e-05 - val_loss: 1.6180e-05
# Epoch 7/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 4.1056e-05 - val_loss: 1.3280e-05
# Epoch 8/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 3.0775e-05 - val_loss: 1.1917e-05
# Epoch 9/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 2.7855e-05 - val_loss: 1.1702e-05
# Epoch 10/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 2.9900e-05 - val_loss: 1.1789e-05
# Epoch 11/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 3.6142e-05 - val_loss: 1.5363e-05
# Epoch 12/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 3.6657e-05 - val_loss: 1.7277e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 5.6945e-04 - val_loss: 2.5810e-05
# Epoch 2/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 4.6055e-05 - val_loss: 2.3640e-05
# Epoch 3/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 6.1328e-05 - val_loss: 1.4819e-05
# Epoch 4/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 3.7604e-05 - val_loss: 1.1112e-05
# Epoch 5/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 2.9173e-05 - val_loss: 1.1489e-05
# Epoch 6/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 3.2933e-05 - val_loss: 1.1114e-05
# Epoch 7/30
# 2278/2278 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - loss: 3.1261e-05 - val_loss: 1.3222e-05
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Average Mean Squared Error: 740419.5378587845
# Average Mean Absolute Error: 348.66268937537814
# Average Mean Absolute Percentage Error: 3.0818843616613556
