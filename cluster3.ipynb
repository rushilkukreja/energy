# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

def preprocess_city_data(file_path, city_name, is_xlsx=False):
    if is_xlsx:
        df = pd.read_excel(file_path)
    else:
        df = pd.read_csv(file_path)
        
    df.dropna(inplace=True)
    
    if city_name in ['Portland', 'Tampa', 'Tuscon', 'Tallahassee', 'El Paso']:
        time_column = 'time'
        demand_column = 'D'
    elif city_name in ['San Diego', 'Omaha']:
        time_column = 'time'
        demand_column = 'Demand (MW)'
    elif city_name == 'Seattle':
        time_column = 'Time'
        demand_column = 'EnergyDemand'
    else:
        raise ValueError(f"City name {city_name} is not recognized. Please add it to the preprocessing logic.")

    df['Time'] = pd.to_datetime(df[time_column])
    
    if city_name in ['Tucson', 'Omaha', 'San Diego']:
        df[demand_column] = df[demand_column].str.replace(',', '').astype(float)
    
    df.rename(columns={demand_column: 'EnergyDemand'}, inplace=True)
    
    df['Hour'] = df['Time'].dt.hour
    df['DayOfWeek'] = df['Time'].dt.dayofweek
    df['Month'] = df['Time'].dt.month
    df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

    for lag in range(1, 25):
        df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

    df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
    df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()
    df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

    df.dropna(inplace=True)

    return df

cities_data = []
city_files = {
    'El Paso': {'path': 'City-Specific Data/ElPaso.csv', 'is_xlsx': False},
    'Omaha': {'path': 'City-Specific Data/Omaha.csv', 'is_xlsx': False},
    'Portland': {'path': 'City-Specific Data/Portland.csv', 'is_xlsx': False},
    'San Diego': {'path': 'City-Specific Data/San Diego.csv', 'is_xlsx': False},
    'Seattle': {'path': 'City-Specific Data/Seattle.xlsx', 'is_xlsx': True},
    'Tallahassee': {'path': 'City-Specific Data/Tallahassee.csv', 'is_xlsx': False},
    'Tampa': {'path': 'City-Specific Data/Tampa.csv', 'is_xlsx': False},
    'Tuscon': {'path': 'City-Specific Data/Tuscon.csv', 'is_xlsx': False},
}

for city, file_info in city_files.items():
    city_data = preprocess_city_data(file_info['path'], city, is_xlsx=file_info['is_xlsx'])
    city_data['City'] = city
    cities_data.append(city_data)


df_all = pd.concat(cities_data, ignore_index=True)


features = df_all[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
                   'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
                   'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
                   'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
                   'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
                   'Temp_RollingMean_24', 'Temp_RollingStd_24',
                   'Temp_Humidity_Interaction']].values
energy_demand = df_all['EnergyDemand'].values.reshape(-1, 1)
dates = df_all['Time'].values


scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=False)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

    # Training the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Making predictions
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate metrics
    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    # Store results
    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)


result_df.to_csv('all_cities_predictions.csv', index=False)


average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")


plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 107s 8ms/step - loss: 2.9531e-04 - val_loss: 1.7477e-06
# Epoch 2/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - loss: 6.7707e-06 - val_loss: 2.1755e-06
# Epoch 3/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - loss: 1.2962e-05 - val_loss: 2.4543e-06
# Epoch 4/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - loss: 1.2034e-05 - val_loss: 2.2843e-06
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 3470/3470 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 2.3876e-04 - val_loss: 1.8339e-06
# Epoch 2/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 88s 7ms/step - loss: 2.4887e-06 - val_loss: 1.3077e-06
# Epoch 3/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 91s 7ms/step - loss: 2.8155e-06 - val_loss: 1.3257e-06
# Epoch 4/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 79s 6ms/step - loss: 2.2586e-06 - val_loss: 1.3456e-06
# Epoch 5/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 73s 6ms/step - loss: 1.8337e-06 - val_loss: 1.6636e-06
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 3470/3470 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 88s 7ms/step - loss: 9.5063e-05 - val_loss: 2.0529e-06
# Epoch 2/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 104s 8ms/step - loss: 9.2452e-06 - val_loss: 1.5880e-06
# Epoch 3/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 81s 6ms/step - loss: 6.7611e-06 - val_loss: 1.3420e-06
# Epoch 4/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 72s 6ms/step - loss: 5.3366e-06 - val_loss: 1.4977e-06
# Epoch 5/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 69s 5ms/step - loss: 7.1573e-06 - val_loss: 1.4894e-06
# Epoch 6/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 73s 6ms/step - loss: 5.1706e-06 - val_loss: 2.6119e-06
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 3470/3470 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 81s 6ms/step - loss: 2.3280e-04 - val_loss: 2.8241e-06
# Epoch 2/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 74s 6ms/step - loss: 3.5011e-06 - val_loss: 1.3186e-06
# Epoch 3/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - loss: 4.3286e-06 - val_loss: 2.1818e-06
# Epoch 4/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 93s 7ms/step - loss: 5.4181e-06 - val_loss: 9.2428e-07
# Epoch 5/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 79s 6ms/step - loss: 4.3086e-06 - val_loss: 1.2068e-06
# Epoch 6/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - loss: 4.9111e-06 - val_loss: 8.0604e-06
# Epoch 7/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 76s 6ms/step - loss: 1.4354e-05 - val_loss: 7.8647e-06
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 3470/3470 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 102s 8ms/step - loss: 3.8252e-04 - val_loss: 4.6624e-06
# Epoch 2/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 4.6140e-06 - val_loss: 7.4400e-06
# Epoch 3/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 80s 6ms/step - loss: 7.2402e-06 - val_loss: 2.4813e-05
# Epoch 4/30
# 12492/12492 ━━━━━━━━━━━━━━━━━━━━ 83s 7ms/step - loss: 1.0415e-05 - val_loss: 5.4912e-06
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 3470/3470 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# Average Mean Squared Error: 176930.38768105916
# Average Mean Absolute Error: 224.96263768867252
# Average Mean Absolute Percentage Error: 29.28473697071293
