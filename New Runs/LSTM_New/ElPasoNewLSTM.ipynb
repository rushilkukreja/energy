# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_excel('/content/ElPasoNew.xlsx')

df.dropna(inplace=True)


df['Hour'] = pd.to_datetime(df['Time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['Time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['Time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)


for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['D'].shift(lag)


df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()


df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']


df.dropna(inplace=True)


features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_RollingMean_24', 'Temp_RollingStd_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['Time'].values


scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=False, random_state=None) #CHANGED from true to false, removed 42 random state

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2), #added dropout layer
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    #adjust patience value below
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )


    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1) #30

    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)

result_df.to_csv('baltimore_predictions.csv', index=False)

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - loss: 0.0096 - val_loss: 0.0013
# Epoch 2/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 3/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - loss: 0.0015 - val_loss: 7.9308e-04
# Epoch 4/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.0014 - val_loss: 7.9364e-04
# Epoch 5/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0012 - val_loss: 6.6740e-04
# Epoch 6/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 37s 14ms/step - loss: 0.0011 - val_loss: 8.6548e-04
# Epoch 7/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0011 - val_loss: 5.7084e-04
# Epoch 8/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0010 - val_loss: 8.5219e-04
# Epoch 9/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - loss: 9.9851e-04 - val_loss: 5.7824e-04
# Epoch 10/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 9.8290e-04 - val_loss: 5.9788e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0140 - val_loss: 0.0019
# Epoch 2/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 3/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.0017 - val_loss: 9.0346e-04
# Epoch 4/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0014 - val_loss: 8.2507e-04
# Epoch 5/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0012 - val_loss: 7.4362e-04
# Epoch 6/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0012 - val_loss: 6.8772e-04
# Epoch 7/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0011 - val_loss: 8.1554e-04
# Epoch 8/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0010 - val_loss: 6.2902e-04
# Epoch 9/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 9.9336e-04 - val_loss: 5.6639e-04
# Epoch 10/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 9.6503e-04 - val_loss: 6.0813e-04
# Epoch 11/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 9.4825e-04 - val_loss: 6.2314e-04
# Epoch 12/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 9.6397e-04 - val_loss: 9.1231e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.0179 - val_loss: 0.0015
# Epoch 2/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 3/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - loss: 0.0019 - val_loss: 8.5469e-04
# Epoch 4/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 0.0015 - val_loss: 8.0476e-04
# Epoch 5/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 6/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - loss: 0.0012 - val_loss: 8.7094e-04
# Epoch 7/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0011 - val_loss: 7.0314e-04
# Epoch 8/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0011 - val_loss: 6.0205e-04
# Epoch 9/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0011 - val_loss: 7.8221e-04
# Epoch 10/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 0.0011 - val_loss: 5.4422e-04
# Epoch 11/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 9.8603e-04 - val_loss: 6.8367e-04
# Epoch 12/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 9.3208e-04 - val_loss: 7.7970e-04
# Epoch 13/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 9.3274e-04 - val_loss: 6.0577e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0276 - val_loss: 0.0018
# Epoch 2/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 3/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 4/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - loss: 0.0016 - val_loss: 8.6299e-04
# Epoch 5/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0015 - val_loss: 8.0511e-04
# Epoch 6/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0013 - val_loss: 7.4032e-04
# Epoch 7/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0013 - val_loss: 9.3580e-04
# Epoch 8/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0013 - val_loss: 7.5119e-04
# Epoch 9/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0012 - val_loss: 6.1230e-04
# Epoch 10/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0012 - val_loss: 6.1202e-04
# Epoch 11/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0012 - val_loss: 8.4317e-04
# Epoch 12/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - loss: 0.0011 - val_loss: 5.6988e-04
# Epoch 13/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0011 - val_loss: 5.7996e-04
# Epoch 14/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0011 - val_loss: 7.0138e-04
# Epoch 15/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - loss: 0.0011 - val_loss: 7.6509e-04
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - loss: 0.0079 - val_loss: 0.0010
# Epoch 2/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 0.0020 - val_loss: 6.4263e-04
# Epoch 3/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - loss: 0.0014 - val_loss: 5.2493e-04
# Epoch 4/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0013 - val_loss: 5.1461e-04
# Epoch 5/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 0.0011 - val_loss: 4.5816e-04
# Epoch 6/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0010 - val_loss: 3.1152e-04
# Epoch 7/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0010 - val_loss: 4.6626e-04
# Epoch 8/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 9.9771e-04 - val_loss: 3.6974e-04
# Epoch 9/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - loss: 9.5968e-04 - val_loss: 2.7818e-04
# Epoch 10/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 9.2337e-04 - val_loss: 3.1996e-04
# Epoch 11/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 9.0100e-04 - val_loss: 3.5212e-04
# Epoch 12/30
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 8.5969e-04 - val_loss: 2.9721e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Average Mean Squared Error: 1966.1238215744008
# Average Mean Absolute Error: 29.09972128962476
# Average Mean Absolute Percentage Error: 2.9092136223568597
