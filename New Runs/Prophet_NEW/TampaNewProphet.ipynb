# %%
import pandas as pd
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel('/content/TampaNew.xlsx')
data = data.dropna()
data['Time'] = pd.to_datetime(data['Time'])
df = data.rename(columns={'Time': 'ds', 'EnergyDemand': 'y'})

df['Hour'] = df['ds'].dt.hour
df['DayOfWeek'] = df['ds'].dt.dayofweek
df['Month'] = df['ds'].dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['y'].shift(lag)

df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

model = Prophet()
model.add_regressor('Temperature')
model.add_regressor('DewPoint')
model.add_regressor('WindSpeed')
model.add_regressor('Pressure')
model.add_regressor('RelativeHumidity')
model.add_regressor('Hour')
model.add_regressor('DayOfWeek')
model.add_regressor('Month')
model.add_regressor('IsWeekend')
model.add_regressor('Temp_RollingMean_24')
model.add_regressor('Temp_RollingStd_24')
model.add_regressor('Temp_Humidity_Interaction')

for lag in range(1, 25):
    model.add_regressor(f'Lag_{lag}')

model.fit(df)

df_cv = cross_validation(model, initial='365 days', period='180 days', horizon='30 days')
df_p = performance_metrics(df_cv)
print("Cross-validation performance metrics:")
print(df_p.head())

val_df = df.iloc[-len(df_cv):]
val_df_future = val_df[['ds', 'Temperature', 'DewPoint', 'WindSpeed', 'Pressure', 'RelativeHumidity',
                        'Hour', 'DayOfWeek', 'Month', 'IsWeekend', 'Temp_RollingMean_24',
                        'Temp_RollingStd_24', 'Temp_Humidity_Interaction'] + [f'Lag_{lag}' for lag in range(1, 25)]]

forecast_val = model.predict(val_df_future)
val_mape = mean_absolute_percentage_error(val_df['y'], forecast_val['yhat'])
print("Validation MAPE:", val_mape)

future = df[['ds', 'Temperature', 'DewPoint', 'WindSpeed', 'Pressure', 'RelativeHumidity',
             'Hour', 'DayOfWeek', 'Month', 'IsWeekend', 'Temp_RollingMean_24',
             'Temp_RollingStd_24', 'Temp_Humidity_Interaction'] + [f'Lag_{lag}' for lag in range(1, 25)]]

forecast = model.predict(future)

df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
aligned_df = df.join(forecast[['yhat']], how='inner')

if len(aligned_df['y']) != len(aligned_df['yhat']):
    print(f"Length mismatch: Actual = {len(aligned_df['y'])}, Predicted = {len(aligned_df['yhat'])}")

plt.figure(figsize=(12, 6))
plt.plot(aligned_df.index, aligned_df['y'], label='Actual', color='b')
plt.plot(aligned_df.index, aligned_df['yhat'], label='Predicted', color='r')
plt.title('Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()

sample_period = 100
plt.figure(figsize=(12, 6))
plt.plot(aligned_df.index[-sample_period:], aligned_df['y'].iloc[-sample_period:], label='Actual', color='b')
plt.plot(aligned_df.index[-sample_period:], aligned_df['yhat'].iloc[-sample_period:], label='Predicted', color='r')
plt.title('Sample of Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()

non_zero_data = aligned_df[aligned_df['y'] != 0]
non_zero_errors = np.abs((non_zero_data['y'] - non_zero_data['yhat']) / non_zero_data['y'])
non_zero_mape = non_zero_errors.mean() * 100
print("MAPE for data:", non_zero_mape)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/y3gr2f_9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/ey720khw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10735', 'data', 'file=/tmp/tmp6yrd0309/y3gr2f_9.json', 'init=/tmp/tmp6yrd0309/ey720khw.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modelfs1sjckn/prophet_model-20250109213831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:38:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:39:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 11 forecasts with cutoffs between 2019-07-19 00:00:00 and 2024-06-22 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/11 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/b_4wk8fv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/wpjhybwc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36485', 'data', 'file=/tmp/tmp6yrd0309/b_4wk8fv.json', 'init=/tmp/tmp6yrd0309/wpjhybwc.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model8esp6g17/prophet_model-20250109213912.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:39:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:39:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/p2ucjrxh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/8zbvd5u8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65046', 'data', 'file=/tmp/tmp6yrd0309/p2ucjrxh.json', 'init=/tmp/tmp6yrd0309/8zbvd5u8.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model7po6yghb/prophet_model-20250109213917.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:39:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:39:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/658t0r2y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/1_jqcx3a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91557', 'data', 'file=/tmp/tmp6yrd0309/658t0r2y.json', 'init=/tmp/tmp6yrd0309/1_jqcx3a.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model6uqu84kj/prophet_model-20250109213928.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:39:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:39:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/76elxxb5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/m52gpned.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24371', 'data', 'file=/tmp/tmp6yrd0309/76elxxb5.json', 'init=/tmp/tmp6yrd0309/m52gpned.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model7xrs0qa2/prophet_model-20250109213941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:39:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:39:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/7monq39r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/cjlqzvv0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2517', 'data', 'file=/tmp/tmp6yrd0309/7monq39r.json', 'init=/tmp/tmp6yrd0309/cjlqzvv0.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modeliccgaxdj/prophet_model-20250109214004.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:40:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:40:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/alhgiyoj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/t0g0gxl6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88166', 'data', 'file=/tmp/tmp6yrd0309/alhgiyoj.json', 'init=/tmp/tmp6yrd0309/t0g0gxl6.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modelc0_ulcui/prophet_model-20250109214030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:40:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:41:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/1_tr1vq5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/qg7reqtj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20286', 'data', 'file=/tmp/tmp6yrd0309/1_tr1vq5.json', 'init=/tmp/tmp6yrd0309/qg7reqtj.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model4lrdrkk_/prophet_model-20250109214108.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:41:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:41:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/c3a3642i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/x9noqcan.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68941', 'data', 'file=/tmp/tmp6yrd0309/c3a3642i.json', 'init=/tmp/tmp6yrd0309/x9noqcan.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modeloahiyhgp/prophet_model-20250109214132.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:41:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:42:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/3qv9dovt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/nrhsoq9v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82920', 'data', 'file=/tmp/tmp6yrd0309/3qv9dovt.json', 'init=/tmp/tmp6yrd0309/nrhsoq9v.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modelhleuo5na/prophet_model-20250109214220.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:42:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:42:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/u22cz5g2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/b6fmh3m2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15724', 'data', 'file=/tmp/tmp6yrd0309/u22cz5g2.json', 'init=/tmp/tmp6yrd0309/b6fmh3m2.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_model2x1pt758/prophet_model-20250109214258.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:42:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:44:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/8p3vw9q6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6yrd0309/paacam9z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83222', 'data', 'file=/tmp/tmp6yrd0309/8p3vw9q6.json', 'init=/tmp/tmp6yrd0309/paacam9z.json', 'output', 'file=/tmp/tmp6yrd0309/prophet_modelcy_urzsj/prophet_model-20250109214424.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:44:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:45:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics:
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 3 days 00:00:00  3619.411286  60.161543  37.226067  0.014794  0.011007
# 1 3 days 01:00:00  3582.969307  59.857909  36.975449  0.014683  0.011007
# 2 3 days 02:00:00  3565.879012  59.714981  36.780676  0.014586  0.010950
# 3 3 days 03:00:00  3566.946349  59.723918  36.801815  0.014598  0.010950
# 4 3 days 04:00:00  3567.643932  59.729758  36.792714  0.014599  0.010810
#
#       smape  coverage
# 0  0.014837  0.914729
# 1  0.014727  0.916021
# 2  0.014628  0.916021
# 3  0.014638  0.916021
# 4  0.014639  0.916021
# Validation MAPE: 0.012819697005779824
# MAPE for data: 1.4005483254457296
