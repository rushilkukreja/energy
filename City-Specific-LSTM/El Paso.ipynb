# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_excel('../City-Specific Data/elpaso.xlsx')
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
    return np.array(sequences), np.array(targets)

seq_length = 24
X, y = create_sequences(features_normalized, energy_demand_normalized, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    loss = model.evaluate(X_test, y_test)
    print(f"Fold Test loss: {loss}")

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    print(f"Fold Mean Squared Error: {mse}")
    print(f"Fold Mean Absolute Error: {mae}")
    print(f"Fold Mean Absolute Percentage Error: {mape}")

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(scaler_energy.inverse_transform(y_test[:100]), label='Actual')
plt.plot(predictions[:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Chicago (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0103 - val_loss: 0.0046
# Epoch 2/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 3/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 4/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 5/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 6/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 7/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 8/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 9/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 10/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 11/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 12/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 13/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 14/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 15/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 16/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 17/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 18/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 19/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 20/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 21/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 22/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 23/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 24/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 25/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0029
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0017
# Fold Test loss: 0.001830833381973207
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 6693.055207647369
# Fold Mean Absolute Error: 63.58933136762842
# Fold Mean Absolute Percentage Error: 6.353843207106688
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0185 - val_loss: 0.0029
# Epoch 2/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 3/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 4/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 5/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 6/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 7/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 8/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 9/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 10/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 11/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 12/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 13/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 14/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 15/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 16/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 17/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 18/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 19/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 20/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 21/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 22/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 23/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 24/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 25/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 0.0028
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017
# Fold Test loss: 0.001827755244448781
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 6681.804903457529
# Fold Mean Absolute Error: 60.89052661044068
# Fold Mean Absolute Percentage Error: 6.148700039319265
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0095 - val_loss: 0.0030
# Epoch 2/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0025 - val_loss: 0.0041
# Epoch 3/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 4/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 5/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 6/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 7/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 8/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 9/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 10/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 11/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 12/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 13/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 14/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 15/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 16/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 17/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 18/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 19/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 20/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 21/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 22/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 23/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 24/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 25/25
# 1176/1176 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 0.0023
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017
# Fold Test loss: 0.0017163087613880634
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 6274.385517364459
# Fold Mean Absolute Error: 61.58981327912947
# Fold Mean Absolute Percentage Error: 6.185577075694398
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0115 - val_loss: 0.0042
# Epoch 2/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 3/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 4/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 5/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 6/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 7/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 8/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 9/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 10/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 11/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 12/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 13/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 14/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 15/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 16/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 17/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 18/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 19/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 20/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 21/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 22/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 23/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 24/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 25/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0016 - val_loss: 0.0024
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018
# Fold Test loss: 0.001731594675220549
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 6330.26778987968
# Fold Mean Absolute Error: 60.95206544767164
# Fold Mean Absolute Percentage Error: 6.109093704711637
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0164 - val_loss: 0.0038
# Epoch 2/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 3/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 4/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 5/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 6/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 7/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 8/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 9/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 10/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 11/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 12/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 13/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 14/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 15/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 16/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 17/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 18/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 19/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 20/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 21/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 22/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 23/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 24/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 25/25
# 1177/1177 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0018 - val_loss: 0.0025
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018
# Fold Test loss: 0.001722655724734068
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 6297.590002555582
# Fold Mean Absolute Error: 60.75586150623812
# Fold Mean Absolute Percentage Error: 6.195614032830099
# Average Mean Squared Error: 6455.420684180923
# Average Mean Absolute Error: 61.55551964222168
# Average Mean Absolute Percentage Error: 6.198565611932418
