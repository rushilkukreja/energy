# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_excel('/content/Baltimore.xlsx')

df.dropna(inplace=True)


df['Hour'] = pd.to_datetime(df['Time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['Time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['Time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)


for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)


df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()


df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']


df.dropna(inplace=True)


features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_RollingMean_24', 'Temp_RollingStd_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)
dates = df['Time'].values


scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=False, random_state=None) #CHANGED from true to false, removed 42 random state

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2), #added dropout layer
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    #adjust patience value below
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )


    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1) #30

    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)

result_df.to_csv('baltimore_predictions.csv', index=False)

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0360 - val_loss: 0.0021
# Epoch 2/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 3/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 4/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 5/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 6/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0016 - val_loss: 7.8013e-04
# Epoch 7/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0015 - val_loss: 6.6077e-04
# Epoch 8/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0014 - val_loss: 5.9937e-04
# Epoch 9/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0013 - val_loss: 6.4730e-04
# Epoch 10/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0013 - val_loss: 7.5444e-04
# Epoch 11/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0013 - val_loss: 7.2853e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.0105 - val_loss: 0.0016
# Epoch 2/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 3/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 4/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0017 - val_loss: 9.3996e-04
# Epoch 5/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0015 - val_loss: 7.8040e-04
# Epoch 6/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0013 - val_loss: 8.0976e-04
# Epoch 7/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0013 - val_loss: 6.3948e-04
# Epoch 8/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0011 - val_loss: 6.6125e-04
# Epoch 9/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0011 - val_loss: 5.2423e-04
# Epoch 10/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0010 - val_loss: 5.3613e-04
# Epoch 11/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0010 - val_loss: 5.2797e-04
# Epoch 12/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0010 - val_loss: 4.9528e-04
# Epoch 13/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0010 - val_loss: 6.2663e-04
# Epoch 14/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 9.9635e-04 - val_loss: 4.9247e-04
# Epoch 15/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 9.9555e-04 - val_loss: 4.8509e-04
# Epoch 16/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 9.6931e-04 - val_loss: 4.5503e-04
# Epoch 17/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 9.7884e-04 - val_loss: 5.4676e-04
# Epoch 18/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 9.4767e-04 - val_loss: 4.8488e-04
# Epoch 19/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 9.6963e-04 - val_loss: 4.2023e-04
# Epoch 20/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 9.4993e-04 - val_loss: 4.0933e-04
# Epoch 21/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 9.1805e-04 - val_loss: 4.6223e-04
# Epoch 22/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 9.2305e-04 - val_loss: 4.6991e-04
# Epoch 23/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 9.3385e-04 - val_loss: 3.9957e-04
# Epoch 24/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 8.6911e-04 - val_loss: 4.2564e-04
# Epoch 25/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 9.5225e-04 - val_loss: 4.4743e-04
# Epoch 26/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - loss: 9.6458e-04 - val_loss: 4.0813e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - loss: 0.0085 - val_loss: 0.0016
# Epoch 2/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 3/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 4/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0017 - val_loss: 8.1262e-04
# Epoch 5/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0015 - val_loss: 8.3610e-04
# Epoch 6/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0014 - val_loss: 9.6581e-04
# Epoch 7/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0013 - val_loss: 7.7152e-04
# Epoch 8/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0012 - val_loss: 8.1518e-04
# Epoch 9/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0012 - val_loss: 4.9392e-04
# Epoch 10/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0011 - val_loss: 5.3729e-04
# Epoch 11/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 4.9258e-04
# Epoch 12/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 5.4162e-04
# Epoch 13/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 4.7929e-04
# Epoch 14/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0011 - val_loss: 4.8381e-04
# Epoch 15/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0011 - val_loss: 4.9721e-04
# Epoch 16/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0010 - val_loss: 4.8861e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0142 - val_loss: 0.0024
# Epoch 2/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 3/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 4/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 5/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0017 - val_loss: 9.3158e-04
# Epoch 6/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0015 - val_loss: 7.9896e-04
# Epoch 7/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0014 - val_loss: 6.1102e-04
# Epoch 8/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0013 - val_loss: 6.0456e-04
# Epoch 9/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0012 - val_loss: 6.0986e-04
# Epoch 10/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0012 - val_loss: 5.6030e-04
# Epoch 11/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0012 - val_loss: 4.9365e-04
# Epoch 12/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 4.9939e-04
# Epoch 13/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0011 - val_loss: 5.3356e-04
# Epoch 14/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 5.6388e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.0177 - val_loss: 0.0020
# Epoch 2/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 3/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 4/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 5/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0017 - val_loss: 9.2308e-04
# Epoch 6/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0015 - val_loss: 7.5747e-04
# Epoch 7/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0014 - val_loss: 6.8787e-04
# Epoch 8/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0013 - val_loss: 8.0355e-04
# Epoch 9/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0012 - val_loss: 7.4476e-04
# Epoch 10/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 0.0012 - val_loss: 5.8311e-04
# Epoch 11/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0012 - val_loss: 5.1391e-04
# Epoch 12/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0012 - val_loss: 5.2628e-04
# Epoch 13/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0011 - val_loss: 6.0021e-04
# Epoch 14/30
# 1128/1128 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 0.0011 - val_loss: 5.2559e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Average Mean Squared Error: 11685.998495338708
# Average Mean Absolute Error: 77.2446130586158
# Average Mean Absolute Percentage Error: 2.198462801987607
