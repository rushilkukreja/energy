# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_csv('../City-Specific Data/Tuscon.csv')
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['time'].values  

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length] 
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)

result_df.to_csv('/Users/sanjeevsubramanian/Downloads/tuscon_predictions.csv', index=False)

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Baltimore (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 1.1694e-04 - val_loss: 1.4345e-05
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.3000e-05 - val_loss: 1.6353e-05
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 6.6668e-05 - val_loss: 1.6510e-05
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.3335e-05 - val_loss: 2.2458e-05
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 5.0352e-05 - val_loss: 1.2718e-05
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - loss: 6.2830e-05 - val_loss: 1.1198e-05
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 2.1585e-05 - val_loss: 1.0833e-05
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 2.5895e-05 - val_loss: 9.0935e-06
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 6.4505e-05 - val_loss: 1.0325e-05
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 4.4739e-05 - val_loss: 1.0229e-05
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 7.5132e-05 - val_loss: 8.2989e-06
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 6.4987e-05 - val_loss: 1.3269e-05
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 6.9148e-05 - val_loss: 9.6776e-06
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.3415e-05 - val_loss: 1.1694e-05
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.6652e-05 - val_loss: 9.8216e-06
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 6.6349e-05 - val_loss: 8.0548e-06
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.1450e-05 - val_loss: 1.0873e-05
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.1778e-05 - val_loss: 9.7773e-06
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 4.2882e-05 - val_loss: 1.0366e-05
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 4.8567e-05 - val_loss: 9.4445e-06
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 6.3074e-05 - val_loss: 1.6525e-05
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.9679e-05 - val_loss: 1.1267e-05
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.8764e-05 - val_loss: 8.4577e-06
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2117e-04 - val_loss: 1.4056e-05
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 7.0593e-05 - val_loss: 1.1317e-05
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 4.2897e-04 - val_loss: 2.0819e-04
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 5.5986e-05 - val_loss: 1.0775e-05
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 4.8656e-05 - val_loss: 1.6836e-05
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.0788e-05 - val_loss: 1.8371e-05
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.0520e-05 - val_loss: 9.0465e-06
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.1735e-04 - val_loss: 1.2655e-05
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 8.5921e-05 - val_loss: 9.0793e-06
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 5.2352e-05 - val_loss: 1.0728e-05
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 5.4084e-05 - val_loss: 1.2309e-05
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 4.6562e-05 - val_loss: 1.2450e-05
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 5.1196e-05 - val_loss: 1.4521e-05
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 2.1808e-05 - val_loss: 1.3300e-05
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 5.8459e-05 - val_loss: 1.3486e-05
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 6.0126e-05 - val_loss: 1.0499e-05
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.9567e-05 - val_loss: 2.0015e-05
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 5.2119e-05 - val_loss: 1.0972e-05
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 2.9112e-05 - val_loss: 9.8831e-06
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 4.4339e-05 - val_loss: 2.1473e-05
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 3.6082e-05 - val_loss: 1.2052e-05
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.1062e-05 - val_loss: 9.4962e-06
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.1419e-05 - val_loss: 1.1197e-05
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 5.8272e-05 - val_loss: 1.2082e-05
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 7.3351e-05 - val_loss: 7.3594e-06
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 3.3797e-05 - val_loss: 8.3859e-06
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - loss: 8.8512e-05 - val_loss: 1.2681e-05
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 1.0017e-04 - val_loss: 1.1804e-05
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.5403e-05 - val_loss: 1.5613e-05
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.0460e-05 - val_loss: 1.2653e-05
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 3.8404e-05 - val_loss: 1.5978e-05
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.1327e-05 - val_loss: 1.5563e-05
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.1936e-05 - val_loss: 1.0045e-05
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 6.7957e-05 - val_loss: 1.2252e-05
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 2.9541e-05 - val_loss: 1.2653e-05
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.2028e-05 - val_loss: 1.0966e-05
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 3.4423e-05 - val_loss: 1.2150e-05
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 3.2531e-05 - val_loss: 1.2966e-04
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 4.6692e-05 - val_loss: 1.3103e-05
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.3218e-05 - val_loss: 8.2808e-05
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 6.8668e-05 - val_loss: 1.2003e-05
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.1162e-05 - val_loss: 1.0834e-05
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 4.8996e-05 - val_loss: 1.1031e-05
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1.3328e-04 - val_loss: 9.0237e-06
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 5.5056e-05 - val_loss: 1.4865e-05
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.9190e-05 - val_loss: 1.0073e-05
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 7.0064e-05 - val_loss: 9.7021e-06
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 5.1675e-05 - val_loss: 8.7145e-06
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.4812e-05 - val_loss: 1.0631e-05
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.0953e-05 - val_loss: 1.1018e-05
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0077e-04 - val_loss: 1.2416e-05
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.8330e-05 - val_loss: 8.6677e-06
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.2380e-04 - val_loss: 1.4136e-05
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 6.0106e-05 - val_loss: 1.1568e-05
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 3.8134e-05 - val_loss: 1.4921e-05
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 4.2956e-05 - val_loss: 1.8038e-05
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 6.4827e-05 - val_loss: 1.2856e-05
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0304e-04 - val_loss: 9.6986e-06
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.4955e-05 - val_loss: 1.3914e-05
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.6706e-05 - val_loss: 8.6700e-06
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.1049e-05 - val_loss: 1.3433e-05
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 5.4932e-05 - val_loss: 1.0507e-05
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.1661e-04 - val_loss: 1.0669e-05
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 9.2823e-05 - val_loss: 8.1001e-06
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 7.2132e-05 - val_loss: 1.4456e-05
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.5992e-05 - val_loss: 1.4267e-05
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 5.5324e-05 - val_loss: 9.4071e-05
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 8.1517e-05 - val_loss: 9.7176e-06
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 4.8755e-05 - val_loss: 1.5645e-05
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.9278e-05 - val_loss: 7.9857e-06
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 4.2236e-05 - val_loss: 8.8307e-06
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 3.9663e-05 - val_loss: 9.3348e-06
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 7.0596e-05 - val_loss: 1.0299e-05
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 5.1808e-05 - val_loss: 8.8065e-06
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 2.6918e-05 - val_loss: 1.0997e-05
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.2779e-04 - val_loss: 9.8110e-06
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.1735e-05 - val_loss: 1.1123e-05
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.1226e-04 - val_loss: 1.4212e-05
# Epoch 2/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 2.3093e-05 - val_loss: 1.1615e-05
# Epoch 3/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 2.1041e-05 - val_loss: 9.9424e-06
# Epoch 4/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.9704e-05 - val_loss: 8.5034e-06
# Epoch 5/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.8971e-05 - val_loss: 1.2202e-05
# Epoch 6/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 1.8767e-05 - val_loss: 1.6984e-05
# Epoch 7/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.8119e-05 - val_loss: 1.0538e-05
# Epoch 8/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 1.8051e-05 - val_loss: 1.3370e-05
# Epoch 9/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.7480e-05 - val_loss: 1.3330e-05
# Epoch 10/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1.7755e-05 - val_loss: 1.8808e-05
# Epoch 11/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.7360e-05 - val_loss: 8.0944e-06
# Epoch 12/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.7508e-05 - val_loss: 1.2986e-05
# Epoch 13/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.6840e-05 - val_loss: 1.4196e-05
# Epoch 14/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.7164e-05 - val_loss: 8.2859e-06
# Epoch 15/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.6568e-05 - val_loss: 1.0837e-05
# Epoch 16/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.6645e-05 - val_loss: 8.4066e-06
# Epoch 17/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.6748e-05 - val_loss: 8.2883e-06
# Epoch 18/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.6653e-05 - val_loss: 8.1325e-06
# Epoch 19/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.6500e-05 - val_loss: 1.3091e-05
# Epoch 20/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1.6589e-05 - val_loss: 1.1590e-05
# Epoch 21/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.6241e-05 - val_loss: 1.1319e-05
# Epoch 22/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.6297e-05 - val_loss: 9.4836e-06
# Epoch 23/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.6203e-05 - val_loss: 1.1952e-05
# Epoch 24/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.6331e-05 - val_loss: 7.7888e-06
# Epoch 25/25
# 1706/1706 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.6298e-05 - val_loss: 1.3324e-05
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Average Mean Squared Error: 184966.8497790012
# Average Mean Absolute Error: 218.70629492537608
# Average Mean Absolute Percentage Error: 16.53867012361095
