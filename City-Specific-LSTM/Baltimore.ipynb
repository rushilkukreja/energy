# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

df = pd.read_excel('../City-Specific Data/Baltimore.xlsx')
df = df.dropna()

temperature = df['Temperature'].values.reshape(-1, 1)
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)

scaler_temp = MinMaxScaler()
scaler_energy = MinMaxScaler()
temperature_normalized = scaler_temp.fit_transform(temperature)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target = data[i+seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

seq_length = 24
X, y = create_sequences(temperature_normalized, seq_length)
y = energy_demand_normalized[seq_length:]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, 1)),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    loss = model.evaluate(X_test, y_test)
    print(f"Fold Test loss: {loss}")

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    print(f"Fold Mean Squared Error: {mse}")
    print(f"Fold Mean Absolute Error: {mae}")
    print(f"Fold Mean Absolute Percentage Error: {mape}")

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")
#Plots
plt.figure(figsize=(12, 6)) 
plt.plot(scaler_energy.inverse_transform(y_test[:100]), label='Actual')
plt.plot(predictions[:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Los Angeles (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0302 - val_loss: 0.0097
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0111 - val_loss: 0.0106
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0102 - val_loss: 0.0115
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - val_loss: 0.0080
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0069 - val_loss: 0.0087
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0069 - val_loss: 0.0087
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0068 - val_loss: 0.0098
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0064 - val_loss: 0.0080
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0062 - val_loss: 0.0083
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0063 - val_loss: 0.0091
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0063 - val_loss: 0.0075
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0061 - val_loss: 0.0096
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0059 - val_loss: 0.0081
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0059 - val_loss: 0.0086
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0060 - val_loss: 0.0074
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0060
# Fold Test loss: 0.005967428907752037
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 124956.58912228837
# Fold Mean Absolute Error: 273.91190815190635
# Fold Mean Absolute Percentage Error: 7.898918129785519
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0254 - val_loss: 0.0107
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0095 - val_loss: 0.0085
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0082 - val_loss: 0.0109
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0075 - val_loss: 0.0078
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0072 - val_loss: 0.0083
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0070 - val_loss: 0.0092
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0066 - val_loss: 0.0074
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0064 - val_loss: 0.0092
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - loss: 0.0064 - val_loss: 0.0089
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0061 - val_loss: 0.0079
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0059 - val_loss: 0.0067
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0059 - val_loss: 0.0083
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0058 - val_loss: 0.0065
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0058 - val_loss: 0.0097
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0058 - val_loss: 0.0071
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0059
# Fold Test loss: 0.005866360850632191
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 122840.3248820611
# Fold Mean Absolute Error: 266.83046966531435
# Fold Mean Absolute Percentage Error: 7.5834771689754525
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0329 - val_loss: 0.0117
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0111 - val_loss: 0.0093
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0100 - val_loss: 0.0095
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0090 - val_loss: 0.0113
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0080 - val_loss: 0.0109
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0072 - val_loss: 0.0084
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0070 - val_loss: 0.0079
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0066 - val_loss: 0.0079
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0063 - val_loss: 0.0076
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0063 - val_loss: 0.0096
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0063 - val_loss: 0.0102
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0061 - val_loss: 0.0087
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0061 - val_loss: 0.0082
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0060 - val_loss: 0.0077
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0059 - val_loss: 0.0088
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0060 - val_loss: 0.0075
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0058 - val_loss: 0.0065
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0058 - val_loss: 0.0079
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0061
# Fold Test loss: 0.006185661535710096
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 129526.3379215534
# Fold Mean Absolute Error: 277.86072042713994
# Fold Mean Absolute Percentage Error: 8.118163921090774
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0256 - val_loss: 0.0099
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0081 - val_loss: 0.0095
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0074 - val_loss: 0.0087
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0065 - val_loss: 0.0088
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0062 - val_loss: 0.0068
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0061 - val_loss: 0.0073
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0060 - val_loss: 0.0085
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0057 - val_loss: 0.0075
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0056 - val_loss: 0.0073
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0059
# Fold Test loss: 0.005806784611195326
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Fold Mean Squared Error: 121592.7817492637
# Fold Mean Absolute Error: 265.4800282597399
# Fold Mean Absolute Percentage Error: 7.541625174047197
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0290 - val_loss: 0.0131
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0150 - val_loss: 0.0091
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0106 - val_loss: 0.0098
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0094 - val_loss: 0.0077
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0083 - val_loss: 0.0092
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0070 - val_loss: 0.0101
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0068 - val_loss: 0.0077
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0066 - val_loss: 0.0092
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0064 - val_loss: 0.0070
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0061 - val_loss: 0.0085
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0062 - val_loss: 0.0086
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0062 - val_loss: 0.0098
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0058 - val_loss: 0.0072
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0059 - val_loss: 0.0077
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0058 - val_loss: 0.0070
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0057 - val_loss: 0.0076
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0059
# Fold Test loss: 0.005774914752691984
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 120925.46232315243
# Fold Mean Absolute Error: 268.0006322385212
# Fold Mean Absolute Percentage Error: 7.7279720875102775
# Average Mean Squared Error: 123968.2991996638
# Average Mean Absolute Error: 270.41675174852435
# Average Mean Absolute Percentage Error: 7.774031296281845
