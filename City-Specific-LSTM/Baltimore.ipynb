# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_excel('../City-Specific Data/Baltimore.xlsx')
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
    return np.array(sequences), np.array(targets)

seq_length = 24
X, y = create_sequences(features_normalized, energy_demand_normalized, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    loss = model.evaluate(X_test, y_test)
    print(f"Fold Test loss: {loss}")

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    print(f"Fold Mean Squared Error: {mse}")
    print(f"Fold Mean Absolute Error: {mae}")
    print(f"Fold Mean Absolute Percentage Error: {mape}")

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(scaler_energy.inverse_transform(y_test[:100]), label='Actual')
plt.plot(predictions[:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Chicago (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0207 - val_loss: 0.0060
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0043 - val_loss: 0.0057
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0040 - val_loss: 0.0059
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0036 - val_loss: 0.0052
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0036 - val_loss: 0.0056
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0040
# Fold Test loss: 0.004030456300824881
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 84396.88210120481
# Fold Mean Absolute Error: 219.4165455579211
# Fold Mean Absolute Percentage Error: 6.337007318402109
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0160 - val_loss: 0.0058
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0073 - val_loss: 0.0063
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0049 - val_loss: 0.0069
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0045 - val_loss: 0.0059
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0036 - val_loss: 0.0047
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0035
# Fold Test loss: 0.003520296886563301
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 73714.22914569582
# Fold Mean Absolute Error: 209.4694558144662
# Fold Mean Absolute Percentage Error: 6.138953204592675
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0248 - val_loss: 0.0060
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0045 - val_loss: 0.0060
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0043 - val_loss: 0.0063
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0038 - val_loss: 0.0053
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0037 - val_loss: 0.0058
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0035 - val_loss: 0.0050
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0058
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0037
# Fold Test loss: 0.003853562753647566
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 80692.74484267762
# Fold Mean Absolute Error: 215.01265090558934
# Fold Mean Absolute Percentage Error: 6.165984818641007
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0197 - val_loss: 0.0064
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0046 - val_loss: 0.0071
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0041 - val_loss: 0.0055
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0037 - val_loss: 0.0052
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0035 - val_loss: 0.0049
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0039
# Fold Test loss: 0.003699961118400097
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 77476.35351042305
# Fold Mean Absolute Error: 210.73751790883964
# Fold Mean Absolute Percentage Error: 6.09880088391241
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0217 - val_loss: 0.0061
# Epoch 2/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 3/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 4/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 5/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 6/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 7/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 8/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 9/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 10/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 11/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 12/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0044 - val_loss: 0.0060
# Epoch 13/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 14/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0042 - val_loss: 0.0052
# Epoch 15/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 16/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 17/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 18/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0039 - val_loss: 0.0065
# Epoch 19/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0039 - val_loss: 0.0052
# Epoch 20/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 21/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 22/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 23/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 24/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 25/25
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0036 - val_loss: 0.0036
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042
# Fold Test loss: 0.003974339924752712
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 83221.79867913456
# Fold Mean Absolute Error: 218.73123954100393
# Fold Mean Absolute Percentage Error: 6.2686512077960135
# Average Mean Squared Error: 79900.40165582717
# Average Mean Absolute Error: 214.67348194556408
# Average Mean Absolute Percentage Error: 6.201879486668842
