# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_csv('../City-Specific Data/San Diego.csv')
column_name = 'Demand (MW)'
df[column_name] = df[column_name].str.replace(',', '').astype(float)
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['Demand (MW)'].values.reshape(-1, 1)
dates = df['time'].values  

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length] 
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)

result_df.to_csv('/Users/sanjeevsubramanian/Downloads/san_diego_predictions.csv', index=False)

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Baltimore (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 0.0135 - val_loss: 0.0079
# Epoch 2/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 3/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 4/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 5/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 6/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0045 - val_loss: 0.0058
# Epoch 7/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0042 - val_loss: 0.0069
# Epoch 8/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0042 - val_loss: 0.0060
# Epoch 9/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 10/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0042 - val_loss: 0.0058
# Epoch 11/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 12/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 13/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 14/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 15/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 16/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 17/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0039 - val_loss: 0.0061
# Epoch 18/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 19/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0038 - val_loss: 0.0066
# Epoch 20/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 21/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0038 - val_loss: 0.0065
# Epoch 22/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 23/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 24/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0036 - val_loss: 0.0055
# Epoch 25/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0036 - val_loss: 0.0062
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.0116 - val_loss: 0.0062
# Epoch 2/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 3/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0049 - val_loss: 0.0068
# Epoch 4/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0046 - val_loss: 0.0065
# Epoch 5/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 6/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 7/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0043 - val_loss: 0.0062
# Epoch 8/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0042 - val_loss: 0.0057
# Epoch 9/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 10/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0041 - val_loss: 0.0065
# Epoch 11/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 12/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 13/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0040 - val_loss: 0.0068
# Epoch 14/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 15/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 16/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0039 - val_loss: 0.0074
# Epoch 17/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0039 - val_loss: 0.0063
# Epoch 18/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0038 - val_loss: 0.0062
# Epoch 19/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 20/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0038 - val_loss: 0.0066
# Epoch 21/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 22/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0038 - val_loss: 0.0070
# Epoch 23/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 24/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 25/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0036 - val_loss: 0.0067
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - loss: 0.0124 - val_loss: 0.0071
# Epoch 2/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 3/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0048 - val_loss: 0.0057
# Epoch 4/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 5/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0044 - val_loss: 0.0073
# Epoch 6/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0043 - val_loss: 0.0061
# Epoch 7/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 8/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0042 - val_loss: 0.0056
# Epoch 9/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0042 - val_loss: 0.0082
# Epoch 10/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0040 - val_loss: 0.0065
# Epoch 11/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0040 - val_loss: 0.0055
# Epoch 12/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 13/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 14/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0040 - val_loss: 0.0067
# Epoch 15/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 16/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0038 - val_loss: 0.0068
# Epoch 17/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 18/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0037 - val_loss: 0.0062
# Epoch 19/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0036 - val_loss: 0.0062
# Epoch 20/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 21/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 22/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0036 - val_loss: 0.0071
# Epoch 23/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 24/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 25/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0035 - val_loss: 0.0059
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0105 - val_loss: 0.0073
# Epoch 2/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0052 - val_loss: 0.0063
# Epoch 3/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0047 - val_loss: 0.0066
# Epoch 4/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0046 - val_loss: 0.0071
# Epoch 5/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0045 - val_loss: 0.0072
# Epoch 6/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0043 - val_loss: 0.0062
# Epoch 7/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 8/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 9/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 10/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 11/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 12/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 13/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0039 - val_loss: 0.0071
# Epoch 14/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 15/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0038 - val_loss: 0.0073
# Epoch 16/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 17/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 18/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0038 - val_loss: 0.0071
# Epoch 19/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 20/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0037 - val_loss: 0.0065
# Epoch 21/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 22/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0037 - val_loss: 0.0065
# Epoch 23/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 24/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 25/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0035 - val_loss: 0.0065
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.0188 - val_loss: 0.0076
# Epoch 2/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 3/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0049 - val_loss: 0.0074
# Epoch 4/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0046 - val_loss: 0.0066
# Epoch 5/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0044 - val_loss: 0.0061
# Epoch 6/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0044 - val_loss: 0.0070
# Epoch 7/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0043 - val_loss: 0.0066
# Epoch 8/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 9/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0042 - val_loss: 0.0063
# Epoch 10/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0043 - val_loss: 0.0063
# Epoch 11/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 12/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 13/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - loss: 0.0040 - val_loss: 0.0063
# Epoch 14/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 15/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 16/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 17/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0039 - val_loss: 0.0067
# Epoch 18/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 19/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 20/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0037 - val_loss: 0.0070
# Epoch 21/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 22/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 23/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0052
# Epoch 24/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 25/25
# 1170/1170 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0036 - val_loss: 0.0064
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Average Mean Squared Error: 68398.36810606069
# Average Mean Absolute Error: 196.59361518087726
# Average Mean Absolute Percentage Error: 10.388897976006678
