# %%
# Baltimore LSTM
# Updates from og version:
# Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# Additional Metrics: MAE, MSE, RMSE, R-squared, MAPE for each forecast horizon

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# data loading and feature engineering
# load dataset and replace 'city.xlsx' with the correct path

try:
    df = pd.read_csv('../../City-Specific Data/Portland.csv')
except FileNotFoundError:
    print("Error: 'Baltimore.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['D'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['time'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# 2. Sequence Creation for Time Series Forecasting
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# 3. Model Training and Evaluation using K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for LSTM Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the LSTM model
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# 4. Display Results
print("\n--- Average Performance Metrics for LSTM Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('LSTM: Predicted vs Actual Energy Demand for Baltimore (1-Hour Horizon)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# --- Starting K-Fold Cross-Validation for LSTM Model ---
#
# --- Fold 1/5 ---
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0020 - val_loss: 1.0536e-04
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 1.5053e-04 - val_loss: 7.1840e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2668e-04 - val_loss: 5.9980e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.1728e-04 - val_loss: 6.3559e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.1097e-04 - val_loss: 5.3367e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.1553e-05 - val_loss: 5.0374e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0600e-04 - val_loss: 5.0399e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.4359e-05 - val_loss: 4.8741e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.1009e-05 - val_loss: 5.0564e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 8.5288e-05 - val_loss: 4.6793e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.0923e-05 - val_loss: 4.2424e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 9.9157e-05 - val_loss: 4.1361e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.3846e-05 - val_loss: 4.8853e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.9929e-05 - val_loss: 4.0938e-05
# Epoch 15/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 8.4656e-05 - val_loss: 4.3179e-05
# Epoch 16/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.6268e-05 - val_loss: 4.0471e-05
# Epoch 17/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 8.2652e-05 - val_loss: 4.2079e-05
# Epoch 18/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 8.4239e-05 - val_loss: 4.6276e-05
# Epoch 19/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 9.1983e-05 - val_loss: 3.8824e-05
# Epoch 20/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 7.9796e-05 - val_loss: 4.1627e-05
# Epoch 21/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.2838e-05 - val_loss: 3.9630e-05
# Epoch 22/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 7.2293e-05 - val_loss: 3.8130e-05
# Epoch 23/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.1133e-04 - val_loss: 3.6960e-05
# Epoch 24/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 8.4796e-05 - val_loss: 4.0953e-05
# Epoch 25/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - loss: 7.2282e-05 - val_loss: 3.9353e-05
# Epoch 26/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - loss: 8.6782e-05 - val_loss: 3.9585e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# --- Fold 2/5 ---
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 0.0019 - val_loss: 1.0272e-04
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 1.3724e-04 - val_loss: 7.5716e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 1.0211e-04 - val_loss: 7.7246e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 9.1806e-05 - val_loss: 5.0263e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 8.5219e-05 - val_loss: 4.8381e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 8.0060e-05 - val_loss: 4.8955e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 7.4867e-05 - val_loss: 4.7187e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 7.2911e-05 - val_loss: 4.7543e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 7.1694e-05 - val_loss: 4.6921e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 6.9254e-05 - val_loss: 4.0658e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 6.7137e-05 - val_loss: 3.9868e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - loss: 6.8161e-05 - val_loss: 3.8559e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.4975e-05 - val_loss: 4.1339e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - loss: 6.3715e-05 - val_loss: 3.9656e-05
# Epoch 15/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 6.5862e-05 - val_loss: 4.2579e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#
# --- Fold 3/5 ---
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0011 - val_loss: 9.4084e-05
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - loss: 1.3337e-04 - val_loss: 7.3528e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - loss: 1.1780e-04 - val_loss: 6.4111e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 1.1196e-04 - val_loss: 7.4048e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0300e-04 - val_loss: 5.4735e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0528e-04 - val_loss: 5.0569e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.5951e-05 - val_loss: 5.1682e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 9.4157e-05 - val_loss: 5.0957e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 8.0790e-05 - val_loss: 4.3184e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 8.4763e-05 - val_loss: 4.1224e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 9.3253e-05 - val_loss: 4.0400e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 7.8755e-05 - val_loss: 5.4002e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 7.2723e-05 - val_loss: 4.0840e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 8.4247e-05 - val_loss: 4.0752e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Fold 4/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 7.9609e-04 - val_loss: 1.1107e-04
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 1.3360e-04 - val_loss: 6.6766e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.1177e-04 - val_loss: 5.9427e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.0660e-04 - val_loss: 5.4011e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.0237e-04 - val_loss: 5.9913e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.8302e-05 - val_loss: 5.0813e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.3398e-05 - val_loss: 4.4654e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 9.2791e-05 - val_loss: 4.6589e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - loss: 7.8542e-05 - val_loss: 4.5528e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 9.2306e-05 - val_loss: 4.2073e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 8.4844e-05 - val_loss: 4.5414e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 8.5366e-05 - val_loss: 4.6303e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.7437e-05 - val_loss: 4.3017e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Fold 5/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0014 - val_loss: 1.3627e-04
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.5627e-04 - val_loss: 9.1700e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.0876e-04 - val_loss: 6.7192e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.2173e-04 - val_loss: 6.6150e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 9.4118e-05 - val_loss: 6.5668e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 9.1046e-05 - val_loss: 7.2771e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 9.2968e-05 - val_loss: 6.3713e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 9.0763e-05 - val_loss: 5.4013e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 8.5735e-05 - val_loss: 6.8626e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 8.0462e-05 - val_loss: 5.9344e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 7.5579e-05 - val_loss: 7.8324e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Average Performance Metrics for LSTM Model ---
#
# Horizon: 1 hours
#   Average MAE: 77.5571
#   Average MSE: 17319.8427
#   Average RMSE: 125.7055
#   Average R2: 0.9098
#   Average MAPE: 3.2161
#
# Horizon: 6 hours
#   Average MAE: 96.6631
#   Average MSE: 22733.9227
#   Average RMSE: 148.0422
#   Average R2: 0.8798
#   Average MAPE: 3.9064
#
# Horizon: 12 hours
#   Average MAE: 107.1362
#   Average MSE: 26553.7377
#   Average RMSE: 160.3489
#   Average R2: 0.8593
#   Average MAPE: 4.3873
#
# Horizon: 24 hours
#   Average MAE: 127.6451
#   Average MSE: 36781.5590
#   Average RMSE: 189.8350
#   Average R2: 0.8042
#   Average MAPE: 5.2175
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
