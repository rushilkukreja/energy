# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_csv('../City-Specific Data/Tampa.csv')
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['time'].values  

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length] 
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)

result_df.to_csv('/Users/sanjeevsubramanian/Downloads/tampa_predictions.csv', index=False)

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Baltimore (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0193 - val_loss: 0.0038
# Epoch 2/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 3/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 4/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 5/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 6/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 7/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 8/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 9/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 10/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 11/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 12/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 13/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 14/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 15/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 16/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 17/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 18/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 19/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 20/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 21/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 22/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 23/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 24/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 25/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0019 - val_loss: 0.0021
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0167 - val_loss: 0.0032
# Epoch 2/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 3/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 4/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 5/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 6/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 7/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 8/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 9/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 10/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 11/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 12/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 13/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 14/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 15/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 16/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 17/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 18/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 19/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 20/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 21/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 22/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 23/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 24/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 25/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0018 - val_loss: 0.0017
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.0240 - val_loss: 0.0031
# Epoch 2/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 3/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 4/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 5/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 6/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 7/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 8/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 9/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 10/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 11/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 12/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 13/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 14/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 15/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 16/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 17/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 18/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 19/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 20/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 21/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 22/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 23/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 24/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 25/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0019 - val_loss: 0.0025
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0123 - val_loss: 0.0033
# Epoch 2/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 3/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 4/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 5/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 6/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 7/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 8/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 9/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 10/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 11/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 12/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 13/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 14/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 15/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 42s 24ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 16/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 17/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 18/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 19/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 20/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 21/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 22/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 23/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 24/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 25/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - loss: 0.0018 - val_loss: 0.0025
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - loss: 0.0191 - val_loss: 0.0031
# Epoch 2/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 3/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 46s 26ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 4/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 43s 24ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 5/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 46s 26ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 6/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 7/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 8/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 49s 28ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 9/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 46s 26ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 10/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 47s 27ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 11/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 12/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 13/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 14/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 31s 17ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 15/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 16/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 68s 39ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 17/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 47s 27ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 18/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 19/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 20/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 21/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 31s 18ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 22/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 23/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 24/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 25/25
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - loss: 0.0019 - val_loss: 0.0020
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# Average Mean Squared Error: 44169.38325052118
# Average Mean Absolute Error: 157.8651194342322
# Average Mean Absolute Percentage Error: 6.391463887861747
