# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error

df = pd.read_excel('../City-Specific Data/tampa.xlsx')
df = df.dropna()

features = df[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)

scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
    return np.array(sequences), np.array(targets)

seq_length = 24
X, y = create_sequences(features_normalized, energy_demand_normalized, seq_length)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    history = model.fit(X_train, y_train, epochs=25, batch_size=32, validation_split=0.1, verbose=1)

    loss = model.evaluate(X_test, y_test)
    print(f"Fold Test loss: {loss}")

    predictions_normalized = model.predict(X_test)

    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    print(f"Fold Mean Squared Error: {mse}")
    print(f"Fold Mean Absolute Error: {mae}")
    print(f"Fold Mean Absolute Percentage Error: {mape}")

average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")

plt.figure(figsize=(12, 6))
plt.plot(scaler_energy.inverse_transform(y_test[:100]), label='Actual')
plt.plot(predictions[:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand for Chicago (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.0195 - val_loss: 0.0058
# Epoch 2/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0072 - val_loss: 0.0054
# Epoch 3/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 4/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 5/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 6/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 7/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 8/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 9/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 10/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 11/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 12/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 34s 29ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 13/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 14/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0051
# Epoch 15/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 16/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 17/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 18/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 19/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 20/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 21/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 22/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 23/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 24/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 25/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0053 - val_loss: 0.0050
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0056
# Fold Test loss: 0.005459357053041458
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Fold Mean Squared Error: 106318.61928670696
# Fold Mean Absolute Error: 246.69790555240203
# Fold Mean Absolute Percentage Error: 10.127383196496178
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - loss: 0.0352 - val_loss: 0.0063
# Epoch 2/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 3/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 4/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 5/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 6/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0064 - val_loss: 0.0051
# Epoch 7/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 8/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 9/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 10/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 11/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 12/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 13/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 14/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 15/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 16/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 17/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 18/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 19/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 20/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 21/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 22/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 23/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 24/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 25/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0055 - val_loss: 0.0052
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0057
# Fold Test loss: 0.0055322181433439255
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Fold Mean Squared Error: 107737.55522770988
# Fold Mean Absolute Error: 253.3080360658237
# Fold Mean Absolute Percentage Error: 10.484584768325133
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.0170 - val_loss: 0.0062
# Epoch 2/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 3/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 4/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 5/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 6/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 7/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 8/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 9/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 10/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 11/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 12/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 13/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 14/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 15/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 16/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 17/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 18/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 19/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 20/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 21/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 22/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 23/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 24/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 25/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0055 - val_loss: 0.0051
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0055
# Fold Test loss: 0.005426893010735512
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Fold Mean Squared Error: 105686.4192715482
# Fold Mean Absolute Error: 249.94113469107896
# Fold Mean Absolute Percentage Error: 10.247594742058281
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0490 - val_loss: 0.0064
# Epoch 2/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 3/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 4/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 5/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 6/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 7/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 8/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 9/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 10/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 30s 26ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 11/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 12/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 13/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 14/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 15/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 16/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 17/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 18/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 19/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 20/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 21/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 22/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 23/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 24/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 25/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0053 - val_loss: 0.0055
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0052
# Fold Test loss: 0.0053534782491624355
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Fold Mean Squared Error: 104256.67864899387
# Fold Mean Absolute Error: 251.09872991361988
# Fold Mean Absolute Percentage Error: 10.436821711966456
# Epoch 1/25
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - loss: 0.0207 - val_loss: 0.0064
# Epoch 2/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 3/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0068 - val_loss: 0.0059
# Epoch 4/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 5/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 6/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 7/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 8/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 9/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 10/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 11/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 12/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 13/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 14/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 15/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 16/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 17/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 18/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 19/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 20/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 21/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 22/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 23/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 24/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 25/25
# 1178/1178 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0053 - val_loss: 0.0053
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0053
# Fold Test loss: 0.005431334022432566
# 328/328 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold Mean Squared Error: 105772.87072927711
# Fold Mean Absolute Error: 247.22936135789027
# Fold Mean Absolute Percentage Error: 10.026108348571453
# Average Mean Squared Error: 105954.42863284722
# Average Mean Absolute Error: 249.65503351616297
# Average Mean Absolute Percentage Error: 10.2644985534835
