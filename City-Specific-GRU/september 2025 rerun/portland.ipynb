# %%
  # Baltimore Energy Demand Forecasting with GRU (Updated)
#
# This script builds and evaluates a Gated Recurrent Unit (GRU) model
# for energy demand forecasting in Baltimore.
#
# Updates from original version:
# - Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# - Additional Metrics: Evaluation includes MAE, MSE, RMSE, R², and MAPE for each forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    df = pd.read_csv('../../City-Specific Data/Portland.csv')
except FileNotFoundError:
    print("Error: 'Baltimore.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['D'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['time'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# --- 2. Sequence Creation for Time Series Forecasting ---
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# --- 3. Model Training and Evaluation using K-Fold Cross-Validation ---
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for GRU Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the GRU model
    model = Sequential([
        GRU(100, activation='tanh', return_sequences=True, input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        GRU(50, activation='tanh'),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=30,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stopping],
        verbose=1
    )

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# --- 4. Display Results ---
print("\n--- Average Performance Metrics for GRU Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('GRU: Predicted vs Actual Energy Demand for Baltimore (1-Hour Horizon)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# --- Starting K-Fold Cross-Validation for GRU Model ---
#
# --- Fold 1/5 ---
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 19ms/step - loss: 6.8801e-04 - val_loss: 6.7919e-05
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 9.9566e-05 - val_loss: 5.4853e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 7.6459e-05 - val_loss: 5.2953e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 8.8683e-05 - val_loss: 4.3464e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 8.1867e-05 - val_loss: 4.3930e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - loss: 6.8963e-05 - val_loss: 4.4565e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.6439e-05 - val_loss: 3.9884e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 7.1320e-05 - val_loss: 4.2130e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 5.9300e-05 - val_loss: 4.0946e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.5839e-05 - val_loss: 3.5720e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - loss: 6.9402e-05 - val_loss: 5.8723e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.0931e-05 - val_loss: 4.1301e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.0165e-05 - val_loss: 5.5821e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#
# --- Fold 2/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - loss: 6.9017e-04 - val_loss: 6.5546e-05
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 8.9956e-05 - val_loss: 5.2653e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 7.2358e-05 - val_loss: 5.2572e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - loss: 6.5600e-05 - val_loss: 4.7609e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.3419e-05 - val_loss: 5.5253e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 5.7742e-05 - val_loss: 4.6135e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 5.6479e-05 - val_loss: 3.9456e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 5.2863e-05 - val_loss: 4.4807e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 5.2904e-05 - val_loss: 4.7190e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 5.1908e-05 - val_loss: 3.8843e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 4.9751e-05 - val_loss: 3.9311e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 4.7235e-05 - val_loss: 4.1405e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - loss: 4.6339e-05 - val_loss: 3.5014e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 4.5263e-05 - val_loss: 3.4534e-05
# Epoch 15/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 4.4204e-05 - val_loss: 3.6112e-05
# Epoch 16/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 4.4336e-05 - val_loss: 3.9981e-05
# Epoch 17/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - loss: 4.3300e-05 - val_loss: 3.5079e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
#
# --- Fold 3/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - loss: 9.0895e-04 - val_loss: 8.3991e-05
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 1.1425e-04 - val_loss: 6.1504e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 1.0648e-04 - val_loss: 6.3835e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - loss: 7.9314e-05 - val_loss: 5.3611e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 8.5253e-05 - val_loss: 4.7764e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.7271e-05 - val_loss: 4.4529e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.6502e-05 - val_loss: 4.2752e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 8.8065e-05 - val_loss: 3.8138e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.0216e-05 - val_loss: 3.6356e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 6.1552e-05 - val_loss: 3.7411e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - loss: 6.0532e-05 - val_loss: 3.5238e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - loss: 5.6361e-05 - val_loss: 3.5656e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 7.3257e-05 - val_loss: 3.5549e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 6.0281e-05 - val_loss: 3.2811e-05
# Epoch 15/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 38s 21ms/step - loss: 5.9989e-05 - val_loss: 3.2865e-05
# Epoch 16/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 5.5417e-05 - val_loss: 3.2334e-05
# Epoch 17/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 5.5392e-05 - val_loss: 3.1542e-05
# Epoch 18/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 5.9863e-05 - val_loss: 3.2630e-05
# Epoch 19/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - loss: 5.7743e-05 - val_loss: 3.4851e-05
# Epoch 20/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 6.3249e-05 - val_loss: 4.1748e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
#
# --- Fold 4/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - loss: 7.8801e-04 - val_loss: 9.2127e-05
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 1.2629e-04 - val_loss: 1.0751e-04
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 1.0215e-04 - val_loss: 5.8331e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 7.8960e-05 - val_loss: 8.3331e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 8.6177e-05 - val_loss: 4.9256e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 8.4725e-05 - val_loss: 4.6706e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.5174e-05 - val_loss: 4.2295e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.0184e-05 - val_loss: 4.4178e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - loss: 7.0188e-05 - val_loss: 3.6937e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - loss: 6.0186e-05 - val_loss: 3.9261e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.7858e-05 - val_loss: 4.0912e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 7.8027e-05 - val_loss: 3.9821e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#
# --- Fold 5/5 ---
# Epoch 1/30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - loss: 8.2546e-04 - val_loss: 1.0203e-04
# Epoch 2/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 1.0376e-04 - val_loss: 8.1149e-05
# Epoch 3/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 39s 22ms/step - loss: 8.3431e-05 - val_loss: 8.0215e-05
# Epoch 4/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 6.9876e-05 - val_loss: 5.8331e-05
# Epoch 5/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - loss: 7.3686e-05 - val_loss: 5.3721e-05
# Epoch 6/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 6.4699e-05 - val_loss: 5.2848e-05
# Epoch 7/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 7.3724e-05 - val_loss: 5.9593e-05
# Epoch 8/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - loss: 7.4267e-05 - val_loss: 4.5389e-05
# Epoch 9/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 7.1215e-05 - val_loss: 4.4970e-05
# Epoch 10/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - loss: 5.7892e-05 - val_loss: 4.7613e-05
# Epoch 11/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.5832e-05 - val_loss: 5.0002e-05
# Epoch 12/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 6.8073e-05 - val_loss: 4.0711e-05
# Epoch 13/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 5.8312e-05 - val_loss: 4.2850e-05
# Epoch 14/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - loss: 6.2969e-05 - val_loss: 4.4446e-05
# Epoch 15/30
# 1756/1756 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - loss: 5.3319e-05 - val_loss: 4.2143e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#
# --- Average Performance Metrics for GRU Model ---
#
# Horizon: 1 hours
#   Average MAE: 62.3686
#   Average MSE: 12343.0811
#   Average RMSE: 105.5942
#   Average R2: 0.9363
#   Average MAPE: 2.5682
#
# Horizon: 6 hours
#   Average MAE: 90.4112
#   Average MSE: 20637.1185
#   Average RMSE: 140.9087
#   Average R2: 0.8912
#   Average MAPE: 3.6696
#
# Horizon: 12 hours
#   Average MAE: 104.7859
#   Average MSE: 25089.9987
#   Average RMSE: 155.6000
#   Average R2: 0.8677
#   Average MAPE: 4.3240
#
# Horizon: 24 hours
#   Average MAE: 116.4490
#   Average MSE: 31548.7418
#   Average RMSE: 175.9969
#   Average R2: 0.8321
#   Average MAPE: 4.6856
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
