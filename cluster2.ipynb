# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error

def preprocess_city_data(file_path, city_name):
    df = pd.read_excel(file_path)
    df.dropna(inplace=True)

    time_column = 'l' if city_name == 'Chicago' else 'Time'
    df['Time'] = pd.to_datetime(df[time_column])

    df['Hour'] = df['Time'].dt.hour
    df['DayOfWeek'] = df['Time'].dt.dayofweek
    df['Month'] = df['Time'].dt.month
    df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

    for lag in range(1, 25):
        df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

    df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
    df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

    df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

    df.dropna(inplace=True)

    return df


cities_data = []
city_files = {
    'Baltimore': 'City-Specific Data/Baltimore.xlsx',
    'NYC': 'City-Specific Data/New York City.xlsx',
    'Philly': 'City-Specific Data/Philadelphia.xlsx',
    'San Antonio': 'City-Specific Data/San Antonio.xlsx',
}

for city, file_path in city_files.items():
    city_data = preprocess_city_data(file_path, city)
    city_data['City'] = city
    cities_data.append(city_data)


df_all = pd.concat(cities_data, ignore_index=True)


features = df_all[['Temperature', 'DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
                   'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
                   'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
                   'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
                   'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
                   'Temp_RollingMean_24', 'Temp_RollingStd_24',
                   'Temp_Humidity_Interaction']].values
energy_demand = df_all['EnergyDemand'].values.reshape(-1, 1)
dates = df_all['Time'].values


scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

def create_sequences(data, target, dates, seq_length):
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target_seq = target[i+seq_length]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length)

kf = KFold(n_splits=5, shuffle=False)

mse_scores = []
mae_scores = []
mape_scores = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

    # Training the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Making predictions
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate metrics
    mse = mean_squared_error(y_test_original, predictions)
    mae = mean_absolute_error(y_test_original, predictions)
    mape = mean_absolute_percentage_error(y_test_original, predictions)
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)

    # Store results
    fold_results = pd.DataFrame({
        'Date': dates_test,
        'Actual': y_test_original.flatten(),
        'Predicted': predictions.flatten()
    })
    result_df = pd.concat([result_df, fold_results], ignore_index=True)


result_df.to_csv('all_cities_predictions.csv', index=False)


average_mse = np.mean(mse_scores)
average_mae = np.mean(mae_scores)
average_mape = np.mean(mape_scores)
print(f"Average Mean Squared Error: {average_mse}")
print(f"Average Mean Absolute Error: {average_mae}")
print(f"Average Mean Absolute Percentage Error: {average_mape}")


plt.figure(figsize=(12, 6))
plt.plot(result_df['Actual'][:100], label='Actual')
plt.plot(result_df['Predicted'][:100], label='Predicted')
plt.title('Predicted vs Actual Energy Demand (Last Fold)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 0.0075 - val_loss: 9.8802e-04
# Epoch 2/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 6.4654e-04 - val_loss: 4.0119e-04
# Epoch 3/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.9282e-04 - val_loss: 4.8986e-04
# Epoch 4/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.4368e-04 - val_loss: 3.4868e-04
# Epoch 5/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.3837e-04 - val_loss: 3.2454e-04
# Epoch 6/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 4.3218e-04 - val_loss: 2.8642e-04
# Epoch 7/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 4.2774e-04 - val_loss: 2.7789e-04
# Epoch 8/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 3.9909e-04 - val_loss: 2.9286e-04
# Epoch 9/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 3.9160e-04 - val_loss: 3.4020e-04
# Epoch 10/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 3.9302e-04 - val_loss: 3.2959e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 1225/1225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 28s 6ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 2/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 7.9874e-04 - val_loss: 5.2119e-04
# Epoch 3/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 5.5656e-04 - val_loss: 3.8043e-04
# Epoch 4/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.9000e-04 - val_loss: 7.0783e-04
# Epoch 5/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.9259e-04 - val_loss: 2.7746e-04
# Epoch 6/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.3840e-04 - val_loss: 3.9856e-04
# Epoch 7/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.4745e-04 - val_loss: 2.9152e-04
# Epoch 8/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 4.4044e-04 - val_loss: 4.1129e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 1225/1225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 28s 6ms/step - loss: 0.0023 - val_loss: 6.2602e-04
# Epoch 2/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 6.4252e-04 - val_loss: 3.9762e-04
# Epoch 3/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 5.3695e-04 - val_loss: 6.6858e-04
# Epoch 4/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 5.0523e-04 - val_loss: 3.5813e-04
# Epoch 5/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 5.0844e-04 - val_loss: 3.2102e-04
# Epoch 6/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 1236s 280ms/step - loss: 4.7172e-04 - val_loss: 4.8493e-04
# Epoch 7/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 2394s 543ms/step - loss: 4.6569e-04 - val_loss: 5.4056e-04
# Epoch 8/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 35s 8ms/step - loss: 4.9011e-04 - val_loss: 3.6809e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 1225/1225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 0.0052 - val_loss: 8.5405e-04
# Epoch 2/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 6.9655e-04 - val_loss: 7.1505e-04
# Epoch 3/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 5.4232e-04 - val_loss: 3.9133e-04
# Epoch 4/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 4.7910e-04 - val_loss: 3.4307e-04
# Epoch 5/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 4.6868e-04 - val_loss: 3.4251e-04
# Epoch 6/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 43s 10ms/step - loss: 4.5151e-04 - val_loss: 3.3539e-04
# Epoch 7/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 4.4370e-04 - val_loss: 3.4790e-04
# Epoch 8/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 4.6368e-04 - val_loss: 3.6563e-04
# Epoch 9/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 28s 6ms/step - loss: 4.4845e-04 - val_loss: 3.7490e-04
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 1225/1225 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - loss: 0.0030 - val_loss: 6.0876e-04
# Epoch 2/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 4.3865e-04 - val_loss: 4.8957e-04
# Epoch 3/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 3.2702e-04 - val_loss: 3.8634e-04
# Epoch 4/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 2.9053e-04 - val_loss: 2.8873e-04
# Epoch 5/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - loss: 2.6934e-04 - val_loss: 2.4531e-04
# Epoch 6/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 2.5822e-04 - val_loss: 2.8934e-04
# Epoch 7/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 2.5331e-04 - val_loss: 2.7019e-04
# Epoch 8/30
# 4408/4408 ━━━━━━━━━━━━━━━━━━━━ 27s 6ms/step - loss: 2.5074e-04 - val_loss: 3.0531e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 1225/1225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Average Mean Squared Error: 49245.67418391218
# Average Mean Absolute Error: 152.4706379091562
# Average Mean Absolute Percentage Error: 2.9531958914558247
