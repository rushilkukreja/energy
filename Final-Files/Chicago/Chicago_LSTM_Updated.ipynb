# %%
# Chicago LSTM
# Updates from og version:
# Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# Additional Metrics: MAE, MSE, RMSE, R-squared, MAPE for each forecast horizon

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# data loading and feature engineering
# load dataset and replace 'city.xlsx' with the correct path

try:
    df = pd.read_excel('Chicago.xlsx')
except FileNotFoundError:
    print("Error: 'Chicago.csv' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['l']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['l']).dt.dayofweek
df['Month'] = pd.to_datetime(df['l']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)
dates = df['l'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# 2. Sequence Creation for time Series Forecasting
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# 3. Model Training and Evaluation using K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for LSTM Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the LSTM model
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# 4. Display Results
print("\n--- Average Performance Metrics for LSTM Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('LSTM: Predicted vs Actual Energy Demand for Baltimore (1-Hour Horizon)')
plt.xlabel('time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# --- Starting K-Fold Cross-Validation for LSTM Model ---
#
# --- Fold 1/5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 8.2862e-04 - val_loss: 5.4264e-05
# Epoch 2/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.2511e-04 - val_loss: 4.2707e-05
# Epoch 3/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.5998e-05 - val_loss: 4.0651e-05
# Epoch 4/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.4336e-05 - val_loss: 3.2370e-05
# Epoch 5/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.1115e-04 - val_loss: 3.1404e-05
# Epoch 6/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 9.4904e-05 - val_loss: 2.9042e-05
# Epoch 7/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 1.0727e-04 - val_loss: 2.9471e-05
# Epoch 8/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.9594e-05 - val_loss: 2.8173e-05
# Epoch 9/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.7079e-05 - val_loss: 2.7999e-05
# Epoch 10/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.0527e-05 - val_loss: 2.8481e-05
# Epoch 11/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0001e-04 - val_loss: 2.5554e-05
# Epoch 12/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.4929e-05 - val_loss: 2.5652e-05
# Epoch 13/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 8.1916e-05 - val_loss: 2.5221e-05
# Epoch 14/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.2185e-04 - val_loss: 2.5727e-05
# Epoch 15/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.0667e-05 - val_loss: 2.4285e-05
# Epoch 16/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 5.8695e-05 - val_loss: 4.0476e-05
# Epoch 17/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.9670e-05 - val_loss: 2.2957e-05
# Epoch 18/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.6461e-05 - val_loss: 2.3861e-05
# Epoch 19/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 9.9751e-05 - val_loss: 2.3994e-05
# Epoch 20/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.7926e-05 - val_loss: 2.4171e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 2/5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 8.9075e-04 - val_loss: 5.6939e-05
# Epoch 2/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 9.1790e-05 - val_loss: 4.1865e-05
# Epoch 3/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.5335e-05 - val_loss: 3.5958e-05
# Epoch 4/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 6.5893e-05 - val_loss: 3.0401e-05
# Epoch 5/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.0558e-05 - val_loss: 3.0323e-05
# Epoch 6/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 5.5264e-05 - val_loss: 2.7048e-05
# Epoch 7/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 5.3157e-05 - val_loss: 2.4009e-05
# Epoch 8/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 5.1837e-05 - val_loss: 2.7856e-05
# Epoch 9/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 4.9501e-05 - val_loss: 2.6683e-05
# Epoch 10/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.9226e-05 - val_loss: 2.2682e-05
# Epoch 11/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.6806e-05 - val_loss: 2.3304e-05
# Epoch 12/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 4.7370e-05 - val_loss: 2.1955e-05
# Epoch 13/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.6440e-05 - val_loss: 2.1909e-05
# Epoch 14/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 4.5672e-05 - val_loss: 2.1719e-05
# Epoch 15/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.5240e-05 - val_loss: 2.0585e-05
# Epoch 16/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 4.5672e-05 - val_loss: 2.4304e-05
# Epoch 17/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.4308e-05 - val_loss: 2.0904e-05
# Epoch 18/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 4.3924e-05 - val_loss: 2.1297e-05
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# --- Fold 3/5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0016 - val_loss: 5.8706e-05
# Epoch 2/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.0268e-04 - val_loss: 4.9277e-05
# Epoch 3/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.7411e-05 - val_loss: 4.1098e-05
# Epoch 4/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.6312e-05 - val_loss: 3.5440e-05
# Epoch 5/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1157e-04 - val_loss: 4.4055e-05
# Epoch 6/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.6457e-05 - val_loss: 3.5522e-05
# Epoch 7/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.1956e-04 - val_loss: 2.9623e-05
# Epoch 8/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 8.2560e-05 - val_loss: 3.0154e-05
# Epoch 9/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0517e-04 - val_loss: 2.6161e-05
# Epoch 10/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0203e-04 - val_loss: 2.6276e-05
# Epoch 11/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.2820e-05 - val_loss: 2.6979e-05
# Epoch 12/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.4398e-05 - val_loss: 2.5448e-05
# Epoch 13/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.0678e-04 - val_loss: 2.5081e-05
# Epoch 14/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.4675e-05 - val_loss: 2.7280e-05
# Epoch 15/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.6063e-05 - val_loss: 2.5007e-05
# Epoch 16/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.0455e-05 - val_loss: 2.4159e-05
# Epoch 17/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.8663e-05 - val_loss: 2.3627e-05
# Epoch 18/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 7.2678e-05 - val_loss: 2.4867e-05
# Epoch 19/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0412e-04 - val_loss: 2.3803e-05
# Epoch 20/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 7.7112e-05 - val_loss: 2.2914e-05
# Epoch 21/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.0299e-05 - val_loss: 2.3602e-05
# Epoch 22/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.7009e-05 - val_loss: 2.2516e-05
# Epoch 23/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 7.3333e-05 - val_loss: 2.3642e-05
# Epoch 24/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.7646e-05 - val_loss: 2.3016e-05
# Epoch 25/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 8.2110e-05 - val_loss: 2.2278e-05
# Epoch 26/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 5.8247e-05 - val_loss: 2.6175e-05
# Epoch 27/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0641e-04 - val_loss: 2.3744e-05
# Epoch 28/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.0563e-04 - val_loss: 2.2858e-05
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 4/5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 0.0017 - val_loss: 5.6061e-05
# Epoch 2/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.1325e-04 - val_loss: 4.1623e-05
# Epoch 3/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0294e-04 - val_loss: 3.5068e-05
# Epoch 4/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.4492e-05 - val_loss: 3.4333e-05
# Epoch 5/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 9.8646e-05 - val_loss: 2.8856e-05
# Epoch 6/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1665e-04 - val_loss: 3.1000e-05
# Epoch 7/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 8.0746e-05 - val_loss: 2.7704e-05
# Epoch 8/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.0990e-05 - val_loss: 2.8592e-05
# Epoch 9/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1379e-04 - val_loss: 3.3021e-05
# Epoch 10/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.3704e-05 - val_loss: 2.9867e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 5/5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0014 - val_loss: 5.1129e-05
# Epoch 2/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.3350e-04 - val_loss: 3.4027e-05
# Epoch 3/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.2180e-04 - val_loss: 2.8133e-05
# Epoch 4/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.2785e-04 - val_loss: 2.6908e-05
# Epoch 5/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.3850e-05 - val_loss: 2.5745e-05
# Epoch 6/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 9.0211e-05 - val_loss: 2.5212e-05
# Epoch 7/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 8.3821e-05 - val_loss: 2.1350e-05
# Epoch 8/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.2589e-04 - val_loss: 2.0585e-05
# Epoch 9/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.5156e-05 - val_loss: 2.1416e-05
# Epoch 10/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 7.5735e-05 - val_loss: 1.8495e-05
# Epoch 11/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 9.4194e-05 - val_loss: 2.0194e-05
# Epoch 12/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.0434e-04 - val_loss: 1.8073e-05
# Epoch 13/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 7.1050e-05 - val_loss: 1.8414e-05
# Epoch 14/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 9.5911e-05 - val_loss: 1.8365e-05
# Epoch 15/30
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 6.9064e-05 - val_loss: 1.8216e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Average Performance Metrics for LSTM Model ---
#
# Horizon: 1 hours
#   Average MAE: 396.2622
#   Average MSE: 790257.1815
#   Average RMSE: 762.4075
#   Average R2: 0.8613
#   Average MAPE: 3.6013
#
# Horizon: 6 hours
#   Average MAE: 541.9760
#   Average MSE: 1073265.1010
#   Average RMSE: 950.0262
#   Average R2: 0.8015
#   Average MAPE: 4.8691
#
# Horizon: 12 hours
#   Average MAE: 652.4830
#   Average MSE: 1213519.5675
#   Average RMSE: 1049.7466
#   Average R2: 0.7649
#   Average MAPE: 5.9291
#
# Horizon: 24 hours
#   Average MAE: 744.1171
#   Average MSE: 1549057.4026
#   Average RMSE: 1198.6711
#   Average R2: 0.6965
#   Average MAPE: 6.6916
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
