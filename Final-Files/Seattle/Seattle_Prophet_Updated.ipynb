# %%
# Baltimore Energy Demand Forecasting with Prophet (Updated & Corrected)
#
# This script uses Facebook's Prophet library for energy demand forecasting in Baltimore.
#
# Updates:
# - Corrected a KeyError by manually calculating the 'horizon' column for metric evaluation.
# - Multi-Horizon Forecasting: Cross-validation is performed with a 24-hour horizon,
#   and performance metrics are calculated for 1, 6, 12, and 24-hour ahead forecasts.
# - Additional Metrics: Evaluation now includes MAE, MSE, RMSE, R², and a robust MAPE
#   for each specific forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    data = pd.read_excel('/content/SeattleNew.xlsx')
except FileNotFoundError:
    print("Error: 'Baltimore.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

data.dropna(inplace=True)
data['Time'] = pd.to_datetime(data['Time'])
df = data.rename(columns={'Time': 'ds', 'EnergyDemand': 'y'})

# Create time-based features
df['Hour'] = df['ds'].dt.hour
df['DayOfWeek'] = df['ds'].dt.dayofweek
df['Month'] = df['ds'].dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['y'].shift(lag)

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# --- 2. Prophet Model Training ---
model = Prophet()

# Add regressors
model.add_regressor('DewPoint')
model.add_regressor('WindSpeed')
model.add_regressor('Pressure')
model.add_regressor('RelativeHumidity')
model.add_regressor('Hour')
model.add_regressor('DayOfWeek')
model.add_regressor('Month')
model.add_regressor('IsWeekend')
model.add_regressor('Temp_Humidity_Interaction')

for lag in range(1, 25):
    model.add_regressor(f'Lag_{lag}')

print("--- Fitting Prophet Model ---")
model.fit(df)

# --- 3. Cross-Validation and Evaluation ---
print("\n--- Starting Cross-Validation ---")
# Perform cross-validation with a horizon that covers all our time steps
df_cv = cross_validation(model, initial='365 days', period='180 days', horizon='24 hours', parallel="processes")

# Display aggregated performance metrics from Prophet
df_p = performance_metrics(df_cv)
print("\nCross-validation performance metrics (aggregated by Prophet):")
print(df_p.head())

# Define a robust MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    if np.sum(non_zero_indices) == 0:
        return 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

# Calculate and display metrics for our specific horizons
print("\n--- Performance Metrics for Specific Horizons ---")
# FIX: Calculate the 'horizon' column manually from 'ds' and 'cutoff'
df_cv['horizon'] = df_cv['ds'] - df_cv['cutoff']
df_cv['horizon_hours'] = df_cv['horizon'].dt.total_seconds() / 3600
horizons = [1, 6, 12, 24]

for h in horizons:
    df_h = df_cv[df_cv['horizon_hours'] == h]
    if not df_h.empty:
        mae = mean_absolute_error(df_h['y'], df_h['yhat'])
        mse = mean_squared_error(df_h['y'], df_h['yhat'])
        rmse = np.sqrt(mse)
        r2 = r2_score(df_h['y'], df_h['yhat'])
        mape = mean_absolute_percentage_error(df_h['y'], df_h['yhat'])

        print(f'\nHorizon: {h} hours')
        print(f'  MAE: {mae:.4f}')
        print(f'  MSE: {mse:.4f}')
        print(f'  RMSE: {rmse:.4f}')
        print(f'  R2 Score: {r2:.4f}')
        print(f'  MAPE: {mape:.4f}%')
    else:
        print(f'\nNo data for horizon: {h} hours')


# --- 4. Final Forecast and Plotting ---
print("\n--- Generating Final Forecast and Plots ---")
future = df.drop(columns=['y'])
forecast = model.predict(future)

# Join forecast with actuals for plotting
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
aligned_df = df.join(forecast[['yhat']], how='inner')

# Plot a sample of the results
sample_period = 100
plt.figure(figsize=(15, 7))
plt.plot(aligned_df.index[-sample_period:], aligned_df['y'].iloc[-sample_period:], label='Actual', color='b', marker='o')
plt.plot(aligned_df.index[-sample_period:], aligned_df['yhat'].iloc[-sample_period:], label='Predicted', color='r', linestyle='--')
plt.title('Prophet: Sample of Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Prophet components
print("\n--- Plotting Prophet Components ---")
fig_components = model.plot_components(forecast)
plt.show()
# Out:
# --- Fitting Prophet Model ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/2xx0etd7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/rp86tzqf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66452', 'data', 'file=/tmp/tmp6eufl95b/2xx0etd7.json', 'init=/tmp/tmp6eufl95b/rp86tzqf.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelmqq6fwi3/prophet_model-20250913043856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:38:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:39:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# --- Starting Cross-Validation ---
# INFO:prophet:Making 11 forecasts with cutoffs between 2019-07-13 17:00:00 and 2024-06-16 17:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7c9f6fb7ec30>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/q7_yr9rp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/wkyuddxo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/vhdi8gpf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44861', 'data', 'file=/tmp/tmp6eufl95b/q7_yr9rp.json', 'init=/tmp/tmp6eufl95b/vhdi8gpf.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelqg2_7y6s/prophet_model-20250913043934.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:39:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/lcjn4ssc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5260', 'data', 'file=/tmp/tmp6eufl95b/wkyuddxo.json', 'init=/tmp/tmp6eufl95b/lcjn4ssc.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_model7g2ajz2n/prophet_model-20250913043936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:39:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:39:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/y6fvifke.json
# 04:39:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/9z_9s5sf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/nw_0bzo9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35750', 'data', 'file=/tmp/tmp6eufl95b/y6fvifke.json', 'init=/tmp/tmp6eufl95b/nw_0bzo9.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelksc_55er/prophet_model-20250913043944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:39:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/iosj_s5i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20792', 'data', 'file=/tmp/tmp6eufl95b/9z_9s5sf.json', 'init=/tmp/tmp6eufl95b/iosj_s5i.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_model1i56dnwg/prophet_model-20250913043949.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:39:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:39:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/lm9y49n3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/l8zmqqve.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79339', 'data', 'file=/tmp/tmp6eufl95b/lm9y49n3.json', 'init=/tmp/tmp6eufl95b/l8zmqqve.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelcs7ixolp/prophet_model-20250913044001.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:40:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:40:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/yk8kfftu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/0efz50ul.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92242', 'data', 'file=/tmp/tmp6eufl95b/yk8kfftu.json', 'init=/tmp/tmp6eufl95b/0efz50ul.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelvl90yld8/prophet_model-20250913044016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:40:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:40:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/dcfxl4k_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/dmej1a40.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84542', 'data', 'file=/tmp/tmp6eufl95b/dcfxl4k_.json', 'init=/tmp/tmp6eufl95b/dmej1a40.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelmz4le_gh/prophet_model-20250913044038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:40:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:40:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/0nqcw787.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/bu27br97.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69525', 'data', 'file=/tmp/tmp6eufl95b/0nqcw787.json', 'init=/tmp/tmp6eufl95b/bu27br97.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelhhp1mlst/prophet_model-20250913044056.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:40:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:41:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/wz_txtq9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/lpve406j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26581', 'data', 'file=/tmp/tmp6eufl95b/wz_txtq9.json', 'init=/tmp/tmp6eufl95b/lpve406j.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_model3gkasx5o/prophet_model-20250913044125.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:41:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:41:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/q6hylkk9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/e18eisw5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4377', 'data', 'file=/tmp/tmp6eufl95b/q6hylkk9.json', 'init=/tmp/tmp6eufl95b/e18eisw5.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelxa5onkx9/prophet_model-20250913044152.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:41:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:42:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/7yk6u5de.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6eufl95b/_bledvln.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21992', 'data', 'file=/tmp/tmp6eufl95b/7yk6u5de.json', 'init=/tmp/tmp6eufl95b/_bledvln.json', 'output', 'file=/tmp/tmp6eufl95b/prophet_modelldd2s3x6/prophet_model-20250913044228.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:42:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:42:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 04:43:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics (aggregated by Prophet):
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 0 days 03:00:00  2597.802221  50.968640  41.752485  0.033095  0.027734
# 1 0 days 04:00:00  2154.192447  46.413279  37.015508  0.031051  0.024099
# 2 0 days 05:00:00  1531.495932  39.134332  30.244899  0.025941  0.022942
# 3 0 days 06:00:00  1199.949886  34.640293  27.297110  0.023610  0.023408
# 4 0 days 07:00:00  1517.434574  38.954263  28.575285  0.026581  0.022218
#
#       smape  coverage
# 0  0.033024       1.0
# 1  0.030690       1.0
# 2  0.025747       1.0
# 3  0.023781       1.0
# 4  0.027246       1.0
#
# --- Performance Metrics for Specific Horizons ---
#
# Horizon: 1 hours
#   MAE: 44.5926
#   MSE: 2633.2793
#   RMSE: 51.3155
#   R2 Score: 0.9473
#   MAPE: 3.4631%
#
# Horizon: 6 hours
#   MAE: 28.1144
#   MSE: 1166.0603
#   RMSE: 34.1476
#   R2 Score: 0.9740
#   MAPE: 2.4748%
#
# Horizon: 12 hours
#   MAE: 20.5678
#   MSE: 697.2112
#   RMSE: 26.4048
#   R2 Score: 0.9759
#   MAPE: 2.4150%
#
# Horizon: 24 hours
#   MAE: 34.4994
#   MSE: 2026.5496
#   RMSE: 45.0172
#   R2 Score: 0.9432
#   MAPE: 3.0491%
#
# --- Generating Final Forecast and Plots ---
# --- Plotting Prophet Components ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1781946795.py in <cell line: 0>()
#     137 # Plot Prophet components
#     138 print("\n--- Plotting Prophet Components ---")
# --> 139 fig_components = model.plot_components(forecast)
#     140 plt.show()
#     141
#
# /usr/local/lib/python3.12/dist-packages/prophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1933         A matplotlib figure.
#    1934         """
# -> 1935         return plot_components(
#    1936             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1937             weekly_start=weekly_start, yearly_start=yearly_start,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     163     for ax, plot_name in zip(axes, components):
#     164         if plot_name == 'trend':
# --> 165             plot_forecast_component(
#     166                 m=m, fcst=fcst, name='trend', ax=ax, uncertainty=uncertainty,
#     167                 plot_cap=plot_cap,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_forecast_component(m, fcst, name, ax, uncertainty, plot_cap, figsize)
#     227         fig = plt.figure(facecolor='w', figsize=figsize)
#     228         ax = fig.add_subplot(111)
# --> 229     fcst_t = fcst['ds']
#     230     artists += ax.plot(fcst_t, fcst[name], ls='-', c='#0072B2')
#     231     if 'cap' in fcst and plot_cap:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ds'
