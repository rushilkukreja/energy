# %%
  # Houston Energy Demand Forecasting with GRU (Updated)
#
# This script builds and evaluates a Gated Recurrent Unit (GRU) model
# for energy demand forecasting in Baltimore.
#
# Updates from original version:
# - Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# - Additional Metrics: Evaluation includes MAE, MSE, RMSE, R², and MAPE for each forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    df = pd.read_excel('/kaggle/input/houston/Houston.xlsx')
except FileNotFoundError:
    print("Error: 'Houston.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['Time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['Time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['Time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)
dates = df['Time'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# --- 2. Sequence Creation for Time Series Forecasting ---
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# --- 3. Model Training and Evaluation using K-Fold Cross-Validation ---
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for GRU Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the GRU model
    model = Sequential([
        GRU(100, activation='tanh', return_sequences=True, input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        GRU(50, activation='tanh'),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=30,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stopping],
        verbose=1
    )

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# --- 4. Display Results ---
print("\n--- Average Performance Metrics for GRU Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('GRU: Predicted vs Actual Energy Demand for Baltimore (1-Hour Horizon)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2025-09-14 04:20:54.734994: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757823655.089199      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757823655.202412      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Starting K-Fold Cross-Validation for GRU Model ---
#
# --- Fold 1/5 ---
# I0000 00:00:1757823676.993386      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1757823676.994061      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# I0000 00:00:1757823682.574904      97 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.0100 - val_loss: 0.0035
# Epoch 2/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 3/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 4/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 5/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 6/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 7/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 8/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 9/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 10/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 11/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 12/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 13/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 2/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0143 - val_loss: 0.0034
# Epoch 2/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 3/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 4/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 5/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 6/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 7/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 8/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 9/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 10/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 11/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 12/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 13/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 14/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 15/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 16/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 17/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 3/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0108 - val_loss: 0.0039
# Epoch 2/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 3/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 4/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 5/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 6/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 7/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 8/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 4/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0138 - val_loss: 0.0035
# Epoch 2/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0046 - val_loss: 0.0033
# Epoch 3/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 4/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 5/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 6/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 7/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 8/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 9/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 10/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 11/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 12/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 13/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Fold 5/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0216 - val_loss: 0.0033
# Epoch 2/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 3/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 4/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 5/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 6/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 7/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 8/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 9/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 10/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 11/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 12/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 13/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 14/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 15/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 16/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 17/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 18/30
# 978/978 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Average Performance Metrics for GRU Model ---
#
# Horizon: 1 hours
#   Average MAE: 331.5139
#   Average MSE: 219891.2710
#   Average RMSE: 462.4759
#   Average R2: 0.9734
#   Average MAPE: 2.5519
#
# Horizon: 6 hours
#   Average MAE: 607.8856
#   Average MSE: 743561.5799
#   Average RMSE: 858.8804
#   Average R2: 0.9069
#   Average MAPE: 4.6952
#
# Horizon: 12 hours
#   Average MAE: 721.1868
#   Average MSE: 1040957.4266
#   Average RMSE: 1014.7068
#   Average R2: 0.8680
#   Average MAPE: 5.6419
#
# Horizon: 24 hours
#   Average MAE: 813.9539
#   Average MSE: 1287635.6239
#   Average RMSE: 1127.8176
#   Average R2: 0.8378
#   Average MAPE: 6.4065
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
