json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97671', 'data', 'file=/tmp/tmpe2cgiudb/hl2ulz_f.json', 'init=/tmp/tmpe2cgiudb/upce3kew.json', 'output', 'file=/tmp/tmpe2cgiudb/prophet_model25xed04c/prophet_model-20250912015014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe2cgiudb/xb20oi1a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27012', 'data', 'file=/tmp/tmpe2cgiudb/umtjdk9l.json', 'init=/tmp/tmpe2cgiudb/xb20oi1a.json', 'output', 'file=/tmp/tmpe2cgiudb/prophet_model5qdq24s5/prophet_model-20250912015020.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:51:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe2cgiudb/crtaf65r.json
# 01:51:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe2cgiudb/g6z1c9q5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89936', 'data', 'file=/tmp/tmpe2cgiudb/crtaf65r.json', 'init=/tmp/tmpe2cgiudb/g6z1c9q5.json', 'output', 'file=/tmp/tmpe2cgiudb/prophet_modelv9kw_upu/prophet_model-20250912015149.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:51:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:52:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics (aggregated by Prophet):
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 0 days 03:00:00  3214.183188  56.693767  41.024815  0.019366  0.013550
# 1 0 days 04:00:00  2147.058893  46.336367  35.827628  0.017656  0.012707
# 2 0 days 05:00:00  2193.400684  46.833756  35.602037  0.018043  0.013096
# 3 0 days 06:00:00  3496.376834  59.130169  46.508597  0.023671  0.016339
# 4 0 days 07:00:00  6498.212554  80.611491  61.105112  0.029736  0.025003
#
#       smape  coverage
# 0  0.019456  0.870629
# 1  0.017575  0.926573
# 2  0.017880  0.944056
# 3  0.023403  0.884615
# 4  0.029834  0.832168
#
# --- Performance Metrics for Specific Horizons ---
#
# Horizon: 1 hours
#   MAE: 55.7399
#   MSE: 6751.6296
#   RMSE: 82.1683
#   R2 Score: 0.7232
#   MAPE: 2.5565%
#
# Horizon: 6 hours
#   MAE: 59.9933
#   MSE: 4967.7775
#   RMSE: 70.4825
#   R2 Score: 0.3951
#   MAPE: 3.0492%
#
# Horizon: 12 hours
#   MAE: 57.7483
#   MSE: 10554.9469
#   RMSE: 102.7373
#   R2 Score: 0.8188
#   MAPE: 3.4295%
#
# Horizon: 24 hours
#   MAE: 29.7797
#   MSE: 1196.9707
#   RMSE: 34.5973
#   R2 Score: 0.9706
#   MAPE: 1.3249%
#
# --- Generating Final Forecast and Plots ---
# --- Plotting Prophet Components ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3567696497.py in <cell line: 0>()
#     137 # Plot Prophet components
#     138 print("\n--- Plotting Prophet Components ---")
# --> 139 fig_components = model.plot_components(forecast)
#     140 plt.show()
#     141
#
# /usr/local/lib/python3.12/dist-packages/prophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1933         A matplotlib figure.
#    1934         """
# -> 1935         return plot_components(
#    1936             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1937             weekly_start=weekly_start, yearly_start=yearly_start,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     163     for ax, plot_name in zip(axes, components):
#     164         if plot_name == 'trend':
# --> 165             plot_forecast_component(
#     166                 m=m, fcst=fcst, name='trend', ax=ax, uncertainty=uncertainty,
#     167                 plot_cap=plot_cap,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_forecast_component(m, fcst, name, ax, uncertainty, plot_cap, figsize)
#     227         fig = plt.figure(facecolor='w', figsize=figsize)
#     228         ax = fig.add_subplot(111)
# --> 229     fcst_t = fcst['ds']
#     230     artists += ax.plot(fcst_t, fcst[name], ls='-', c='#0072B2')
#     231     if 'cap' in fcst and plot_cap:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ds'
