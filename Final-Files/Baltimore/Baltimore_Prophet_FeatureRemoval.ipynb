# %%
# Baltimore Energy Demand Forecasting with Prophet (Updated & Corrected)
#
# This script uses Facebook's Prophet library for energy demand forecasting in Baltimore.
#
# Updates:
# - Corrected a KeyError by manually calculating the 'horizon' column for metric evaluation.
# - Multi-Horizon Forecasting: Cross-validation is performed with a 24-hour horizon,
#   and performance metrics are calculated for 1, 6, 12, and 24-hour ahead forecasts.
# - Additional Metrics: Evaluation now includes MAE, MSE, RMSE, R², and a robust MAPE
#   for each specific forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    data = pd.read_excel('Baltimore.xlsx')
except FileNotFoundError:
    print("Error: 'Baltimore.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

data.dropna(inplace=True)
data['Time'] = pd.to_datetime(data['Time'])
df = data.rename(columns={'Time': 'ds', 'EnergyDemand': 'y'})

# Create time-based features
df['Hour'] = df['ds'].dt.hour
df['DayOfWeek'] = df['ds'].dt.dayofweek
df['Month'] = df['ds'].dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['y'].shift(lag)

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# --- 2. Prophet Model Training ---
model = Prophet()

# Add regressors
model.add_regressor('DewPoint')
model.add_regressor('WindSpeed')
model.add_regressor('Pressure')
model.add_regressor('RelativeHumidity')
model.add_regressor('Hour')
model.add_regressor('DayOfWeek')
model.add_regressor('Month')
model.add_regressor('IsWeekend')
model.add_regressor('Temp_Humidity_Interaction')

for lag in range(1, 25):
    model.add_regressor(f'Lag_{lag}')

print("--- Fitting Prophet Model ---")
model.fit(df)

# --- 3. Cross-Validation and Evaluation ---
print("\n--- Starting Cross-Validation ---")
# Perform cross-validation with a horizon that covers all our time steps
df_cv = cross_validation(model, initial='365 days', period='180 days', horizon='24 hours', parallel="processes")

# Display aggregated performance metrics from Prophet
df_p = performance_metrics(df_cv)
print("\nCross-validation performance metrics (aggregated by Prophet):")
print(df_p.head())

# Define a robust MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    if np.sum(non_zero_indices) == 0:
        return 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

# Calculate and display metrics for our specific horizons
print("\n--- Performance Metrics for Specific Horizons ---")
# FIX: Calculate the 'horizon' column manually from 'ds' and 'cutoff'
df_cv['horizon'] = df_cv['ds'] - df_cv['cutoff']
df_cv['horizon_hours'] = df_cv['horizon'].dt.total_seconds() / 3600
horizons = [1, 6, 12, 24]

for h in horizons:
    df_h = df_cv[df_cv['horizon_hours'] == h]
    if not df_h.empty:
        mae = mean_absolute_error(df_h['y'], df_h['yhat'])
        mse = mean_squared_error(df_h['y'], df_h['yhat'])
        rmse = np.sqrt(mse)
        r2 = r2_score(df_h['y'], df_h['yhat'])
        mape = mean_absolute_percentage_error(df_h['y'], df_h['yhat'])

        print(f'\nHorizon: {h} hours')
        print(f'  MAE: {mae:.4f}')
        print(f'  MSE: {mse:.4f}')
        print(f'  RMSE: {rmse:.4f}')
        print(f'  R2 Score: {r2:.4f}')
        print(f'  MAPE: {mape:.4f}%')
    else:
        print(f'\nNo data for horizon: {h} hours')


# --- 4. Final Forecast and Plotting ---
print("\n--- Generating Final Forecast and Plots ---")
future = df.drop(columns=['y'])
forecast = model.predict(future)

# Join forecast with actuals for plotting
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
aligned_df = df.join(forecast[['yhat']], how='inner')

# Plot a sample of the results
sample_period = 100
plt.figure(figsize=(15, 7))
plt.plot(aligned_df.index[-sample_period:], aligned_df['y'].iloc[-sample_period:], label='Actual', color='b', marker='o')
plt.plot(aligned_df.index[-sample_period:], aligned_df['yhat'].iloc[-sample_period:], label='Predicted', color='r', linestyle='--')
plt.title('Prophet: Sample of Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Prophet components
print("\n--- Plotting Prophet Components ---")
fig_components = model.plot_components(forecast)
plt.show()
# Out:
# --- Fitting Prophet Model ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/7kectmnq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/ku1pfuv0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27005', 'data', 'file=/tmp/tmpih2bv3ko/7kectmnq.json', 'init=/tmp/tmpih2bv3ko/ku1pfuv0.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_model12t1ug6y/prophet_model-20250914040637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:06:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:07:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# --- Starting Cross-Validation ---
# INFO:prophet:Making 11 forecasts with cutoffs between 2019-07-14 00:00:00 and 2024-06-17 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7a0b3dfdf4d0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/ca38z5l0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/pvrvt4t_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/3620w2j6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69029', 'data', 'file=/tmp/tmpih2bv3ko/ca38z5l0.json', 'init=/tmp/tmpih2bv3ko/3620w2j6.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modela1svzo96/prophet_model-20250914040731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:07:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/7em9cqzu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91367', 'data', 'file=/tmp/tmpih2bv3ko/pvrvt4t_.json', 'init=/tmp/tmpih2bv3ko/7em9cqzu.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelj7nn1q1v/prophet_model-20250914040733.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:07:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:07:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/o0m0g6ks.json
# 04:07:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/0pgxkkhq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/fw037zct.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69581', 'data', 'file=/tmp/tmpih2bv3ko/o0m0g6ks.json', 'init=/tmp/tmpih2bv3ko/fw037zct.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_model2grxp3m0/prophet_model-20250914040745.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:07:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/lg0px_j9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48794', 'data', 'file=/tmp/tmpih2bv3ko/0pgxkkhq.json', 'init=/tmp/tmpih2bv3ko/lg0px_j9.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelcp530luv/prophet_model-20250914040749.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:07:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 04:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/_z_i8qp6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/o437zrxt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/2va5qw8n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8785', 'data', 'file=/tmp/tmpih2bv3ko/_z_i8qp6.json', 'init=/tmp/tmpih2bv3ko/2va5qw8n.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelx4t5c36z/prophet_model-20250914040815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/rubn__u0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35718', 'data', 'file=/tmp/tmpih2bv3ko/o437zrxt.json', 'init=/tmp/tmpih2bv3ko/rubn__u0.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelyz2qlp14/prophet_model-20250914040816.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:08:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:08:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/576s99ji.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/qu2h3utn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62131', 'data', 'file=/tmp/tmpih2bv3ko/576s99ji.json', 'init=/tmp/tmpih2bv3ko/qu2h3utn.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelexs6lsf3/prophet_model-20250914040857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:08:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:09:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/0qty5566.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/6347o8qp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61958', 'data', 'file=/tmp/tmpih2bv3ko/0qty5566.json', 'init=/tmp/tmpih2bv3ko/6347o8qp.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelthxktfb2/prophet_model-20250914040911.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:09:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/6x7s3s1c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/b68yaq7y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31928', 'data', 'file=/tmp/tmpih2bv3ko/6x7s3s1c.json', 'init=/tmp/tmpih2bv3ko/b68yaq7y.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modelpvdvvzsm/prophet_model-20250914040948.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:09:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/vj68ji7_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/ub4pyfz1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84844', 'data', 'file=/tmp/tmpih2bv3ko/vj68ji7_.json', 'init=/tmp/tmpih2bv3ko/ub4pyfz1.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_modeleuoonpwm/prophet_model-20250914041045.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:10:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:11:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/1ltxmy7v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpih2bv3ko/xl37304c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26876', 'data', 'file=/tmp/tmpih2bv3ko/1ltxmy7v.json', 'init=/tmp/tmpih2bv3ko/xl37304c.json', 'output', 'file=/tmp/tmpih2bv3ko/prophet_model13layqy0/prophet_model-20250914041117.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:11:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:12:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 04:12:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics (aggregated by Prophet):
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 0 days 03:00:00   527.834875  22.974657  17.931295  0.005636  0.004122
# 1 0 days 04:00:00   904.987276  30.083006  24.338703  0.008092  0.007123
# 2 0 days 05:00:00  1466.622378  38.296506  32.689432  0.011064  0.009897
# 3 0 days 06:00:00  1965.201516  44.330593  36.761942  0.012277  0.010490
# 4 0 days 07:00:00  2308.766104  48.049621  39.160840  0.012498  0.010625
#
#       smape  coverage
# 0  0.005639  1.000000
# 1  0.008058  1.000000
# 2  0.010989  1.000000
# 3  0.012197  0.961538
# 4  0.012429  0.884615
#
# --- Performance Metrics for Specific Horizons ---
#
# Horizon: 1 hours
#   MAE: 16.8647
#   MSE: 511.2048
#   RMSE: 22.6098
#   R2 Score: 0.9988
#   MAPE: 0.5033%
#
# Horizon: 6 hours
#   MAE: 36.9673
#   MSE: 2267.7375
#   RMSE: 47.6208
#   R2 Score: 0.9964
#   MAPE: 1.2099%
#
# Horizon: 12 hours
#   MAE: 59.2229
#   MSE: 4514.7921
#   RMSE: 67.1922
#   R2 Score: 0.9877
#   MAPE: 1.4903%
#
# Horizon: 24 hours
#   MAE: 12.0533
#   MSE: 195.7111
#   RMSE: 13.9897
#   R2 Score: 0.9994
#   MAPE: 0.3363%
#
# --- Generating Final Forecast and Plots ---
# --- Plotting Prophet Components ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1186340376.py in <cell line: 0>()
#     137 # Plot Prophet components
#     138 print("\n--- Plotting Prophet Components ---")
# --> 139 fig_components = model.plot_components(forecast)
#     140 plt.show()
#     141
#
# /usr/local/lib/python3.12/dist-packages/prophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1933         A matplotlib figure.
#    1934         """
# -> 1935         return plot_components(
#    1936             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1937             weekly_start=weekly_start, yearly_start=yearly_start,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     163     for ax, plot_name in zip(axes, components):
#     164         if plot_name == 'trend':
# --> 165             plot_forecast_component(
#     166                 m=m, fcst=fcst, name='trend', ax=ax, uncertainty=uncertainty,
#     167                 plot_cap=plot_cap,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_forecast_component(m, fcst, name, ax, uncertainty, plot_cap, figsize)
#     227         fig = plt.figure(facecolor='w', figsize=figsize)
#     228         ax = fig.add_subplot(111)
# --> 229     fcst_t = fcst['ds']
#     230     artists += ax.plot(fcst_t, fcst[name], ls='-', c='#0072B2')
#     231     if 'cap' in fcst and plot_cap:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ds'
