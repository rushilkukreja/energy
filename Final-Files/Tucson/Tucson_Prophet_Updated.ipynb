# %%
# Baltimore Energy Demand Forecasting with Prophet (Updated & Corrected)
#
# This script uses Facebook's Prophet library for energy demand forecasting in Baltimore.
#
# Updates:
# - Corrected a KeyError by manually calculating the 'horizon' column for metric evaluation.
# - Multi-Horizon Forecasting: Cross-validation is performed with a 24-hour horizon,
#   and performance metrics are calculated for 1, 6, 12, and 24-hour ahead forecasts.
# - Additional Metrics: Evaluation now includes MAE, MSE, RMSE, R², and a robust MAPE
#   for each specific forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    data = pd.read_excel('/content/TusconNew.xlsx')
except FileNotFoundError:
    print("Error: 'Baltimore.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

data.dropna(inplace=True)
data['Time'] = pd.to_datetime(data['Time'])
df = data.rename(columns={'Time': 'ds', 'EnergyDemand': 'y'})

# Create time-based features
df['Hour'] = df['ds'].dt.hour
df['DayOfWeek'] = df['ds'].dt.dayofweek
df['Month'] = df['ds'].dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['y'].shift(lag)

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# --- 2. Prophet Model Training ---
model = Prophet()

# Add regressors
model.add_regressor('DewPoint')
model.add_regressor('WindSpeed')
model.add_regressor('Pressure')
model.add_regressor('RelativeHumidity')
model.add_regressor('Hour')
model.add_regressor('DayOfWeek')
model.add_regressor('Month')
model.add_regressor('IsWeekend')
model.add_regressor('Temp_Humidity_Interaction')

for lag in range(1, 25):
    model.add_regressor(f'Lag_{lag}')

print("--- Fitting Prophet Model ---")
model.fit(df)

# --- 3. Cross-Validation and Evaluation ---
print("\n--- Starting Cross-Validation ---")
# Perform cross-validation with a horizon that covers all our time steps
df_cv = cross_validation(model, initial='365 days', period='180 days', horizon='24 hours', parallel="processes")

# Display aggregated performance metrics from Prophet
df_p = performance_metrics(df_cv)
print("\nCross-validation performance metrics (aggregated by Prophet):")
print(df_p.head())

# Define a robust MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    if np.sum(non_zero_indices) == 0:
        return 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

# Calculate and display metrics for our specific horizons
print("\n--- Performance Metrics for Specific Horizons ---")
# FIX: Calculate the 'horizon' column manually from 'ds' and 'cutoff'
df_cv['horizon'] = df_cv['ds'] - df_cv['cutoff']
df_cv['horizon_hours'] = df_cv['horizon'].dt.total_seconds() / 3600
horizons = [1, 6, 12, 24]

for h in horizons:
    df_h = df_cv[df_cv['horizon_hours'] == h]
    if not df_h.empty:
        mae = mean_absolute_error(df_h['y'], df_h['yhat'])
        mse = mean_squared_error(df_h['y'], df_h['yhat'])
        rmse = np.sqrt(mse)
        r2 = r2_score(df_h['y'], df_h['yhat'])
        mape = mean_absolute_percentage_error(df_h['y'], df_h['yhat'])

        print(f'\nHorizon: {h} hours')
        print(f'  MAE: {mae:.4f}')
        print(f'  MSE: {mse:.4f}')
        print(f'  RMSE: {rmse:.4f}')
        print(f'  R2 Score: {r2:.4f}')
        print(f'  MAPE: {mape:.4f}%')
    else:
        print(f'\nNo data for horizon: {h} hours')


# --- 4. Final Forecast and Plotting ---
print("\n--- Generating Final Forecast and Plots ---")
future = df.drop(columns=['y'])
forecast = model.predict(future)

# Join forecast with actuals for plotting
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
aligned_df = df.join(forecast[['yhat']], how='inner')

# Plot a sample of the results
sample_period = 100
plt.figure(figsize=(15, 7))
plt.plot(aligned_df.index[-sample_period:], aligned_df['y'].iloc[-sample_period:], label='Actual', color='b', marker='o')
plt.plot(aligned_df.index[-sample_period:], aligned_df['yhat'].iloc[-sample_period:], label='Predicted', color='r', linestyle='--')
plt.title('Prophet: Sample of Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Prophet components
print("\n--- Plotting Prophet Components ---")
fig_components = model.plot_components(forecast)
plt.show()
# Out:
# --- Fitting Prophet Model ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/dqulbjy9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/e0dlb39q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53341', 'data', 'file=/tmp/tmpn61v8coz/dqulbjy9.json', 'init=/tmp/tmpn61v8coz/e0dlb39q.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_model8q4h22wv/prophet_model-20250913052325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:23:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# --- Starting Cross-Validation ---
# INFO:prophet:Making 11 forecasts with cutoffs between 2019-08-17 00:00:00 and 2024-07-21 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x79c1f4ddb860>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/myd5sgo8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/hhl3x5da.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/b0ut1kvm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13851', 'data', 'file=/tmp/tmpn61v8coz/myd5sgo8.json', 'init=/tmp/tmpn61v8coz/b0ut1kvm.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_model4m7g6jmi/prophet_model-20250913052419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/lniym0hk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38514', 'data', 'file=/tmp/tmpn61v8coz/hhl3x5da.json', 'init=/tmp/tmpn61v8coz/lniym0hk.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelbui9wksb/prophet_model-20250913052421.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/yyrh5hj8.json
# 05:24:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/fis_4hub.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/npbhb9i3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96703', 'data', 'file=/tmp/tmpn61v8coz/yyrh5hj8.json', 'init=/tmp/tmpn61v8coz/npbhb9i3.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelv7btcug5/prophet_model-20250913052438.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/e_tql18d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64844', 'data', 'file=/tmp/tmpn61v8coz/fis_4hub.json', 'init=/tmp/tmpn61v8coz/e_tql18d.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_model9sx0z6fb/prophet_model-20250913052443.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:25:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/cczyp2mn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/4cnutk94.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89388', 'data', 'file=/tmp/tmpn61v8coz/cczyp2mn.json', 'init=/tmp/tmpn61v8coz/4cnutk94.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_model05579hi8/prophet_model-20250913052513.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:25:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:25:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/yr1qrlyn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/7x5lv9pn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11841', 'data', 'file=/tmp/tmpn61v8coz/yr1qrlyn.json', 'init=/tmp/tmpn61v8coz/7x5lv9pn.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelovadc2g8/prophet_model-20250913052528.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:25:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:25:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/3529v2w1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/_r16rdf6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85093', 'data', 'file=/tmp/tmpn61v8coz/3529v2w1.json', 'init=/tmp/tmpn61v8coz/_r16rdf6.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelg5uxb5su/prophet_model-20250913052609.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:26:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:26:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/2l8i8mw9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/gjw_f50l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41314', 'data', 'file=/tmp/tmpn61v8coz/2l8i8mw9.json', 'init=/tmp/tmpn61v8coz/gjw_f50l.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modeld9e7anb8/prophet_model-20250913052627.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:26:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:27:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/bzizzsay.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/h2elwudu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47360', 'data', 'file=/tmp/tmpn61v8coz/bzizzsay.json', 'init=/tmp/tmpn61v8coz/h2elwudu.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelwak_a94y/prophet_model-20250913052718.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:27:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/ym8jd2vu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/5c4r7fpi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34370', 'data', 'file=/tmp/tmpn61v8coz/ym8jd2vu.json', 'init=/tmp/tmpn61v8coz/5c4r7fpi.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelfs7kdxr8/prophet_model-20250913052735.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/w7zqk51q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpn61v8coz/ybewyv3u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64787', 'data', 'file=/tmp/tmpn61v8coz/w7zqk51q.json', 'init=/tmp/tmpn61v8coz/ybewyv3u.json', 'output', 'file=/tmp/tmpn61v8coz/prophet_modelpw6wwnz7/prophet_model-20250913052848.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:29:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:30:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics (aggregated by Prophet):
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 0 days 03:00:00   699.254267  26.443416  18.439513  0.012526  0.008819
# 1 0 days 04:00:00   502.656074  22.419993  17.305329  0.012159  0.010446
# 2 0 days 05:00:00  1401.013641  37.430117  28.492846  0.019569  0.016702
# 3 0 days 06:00:00  2404.281731  49.033476  38.857295  0.026002  0.022703
# 4 0 days 07:00:00  3697.320843  60.805599  48.644815  0.031209  0.028336
#
#       smape  coverage
# 0  0.012622  1.000000
# 1  0.012102  1.000000
# 2  0.019518  0.961538
# 3  0.026074  0.961538
# 4  0.031551  0.909091
#
# --- Performance Metrics for Specific Horizons ---
#
# Horizon: 1 hours
#   MAE: 35.0289
#   MSE: 1912.2606
#   RMSE: 43.7294
#   R2 Score: 0.9774
#   MAPE: 2.3130%
#
# Horizon: 6 hours
#   MAE: 42.9949
#   MSE: 2898.2210
#   RMSE: 53.8351
#   R2 Score: 0.8957
#   MAPE: 2.8304%
#
# Horizon: 12 hours
#   MAE: 70.5490
#   MSE: 6553.7843
#   RMSE: 80.9554
#   R2 Score: 0.9845
#   MAPE: 4.8086%
#
# Horizon: 24 hours
#   MAE: 22.6890
#   MSE: 743.4698
#   RMSE: 27.2666
#   R2 Score: 0.9928
#   MAPE: 1.4463%
#
# --- Generating Final Forecast and Plots ---
# --- Plotting Prophet Components ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-763124626.py in <cell line: 0>()
#     137 # Plot Prophet components
#     138 print("\n--- Plotting Prophet Components ---")
# --> 139 fig_components = model.plot_components(forecast)
#     140 plt.show()
#     141
#
# /usr/local/lib/python3.12/dist-packages/prophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1933         A matplotlib figure.
#    1934         """
# -> 1935         return plot_components(
#    1936             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1937             weekly_start=weekly_start, yearly_start=yearly_start,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     163     for ax, plot_name in zip(axes, components):
#     164         if plot_name == 'trend':
# --> 165             plot_forecast_component(
#     166                 m=m, fcst=fcst, name='trend', ax=ax, uncertainty=uncertainty,
#     167                 plot_cap=plot_cap,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_forecast_component(m, fcst, name, ax, uncertainty, plot_cap, figsize)
#     227         fig = plt.figure(facecolor='w', figsize=figsize)
#     228         ax = fig.add_subplot(111)
# --> 229     fcst_t = fcst['ds']
#     230     artists += ax.plot(fcst_t, fcst[name], ls='-', c='#0072B2')
#     231     if 'cap' in fcst and plot_cap:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ds'
