# %%
# ElPaso Energy Demand Forecasting with Prophet (Updated & Corrected)
#
# This script uses Facebook's Prophet library for energy demand forecasting in Baltimore.
#
# Updates:
# - Corrected a KeyError by manually calculating the 'horizon' column for metric evaluation.
# - Multi-Horizon Forecasting: Cross-validation is performed with a 24-hour horizon,
#   and performance metrics are calculated for 1, 6, 12, and 24-hour ahead forecasts.
# - Additional Metrics: Evaluation now includes MAE, MSE, RMSE, R², and a robust MAPE
#   for each specific forecast horizon.

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# --- 1. Data Loading and Feature Engineering ---
# Load the dataset
# Make sure to replace 'Baltimore.xlsx' with the correct path if the file is not in the same directory.
try:
    data = pd.read_csv('ElPaso.csv')
except FileNotFoundError:
    print("Error: 'ElPaso.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

data.dropna(inplace=True)
data['time'] = pd.to_datetime(data['time'])
df = data.rename(columns={'time': 'ds', 'D': 'y'})

# Create time-based features
df['Hour'] = df['ds'].dt.hour
df['DayOfWeek'] = df['ds'].dt.dayofweek
df['Month'] = df['ds'].dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['y'].shift(lag)

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# --- 2. Prophet Model Training ---
model = Prophet()

# Add regressors
model.add_regressor('DewPoint')
model.add_regressor('WindSpeed')
model.add_regressor('Pressure')
model.add_regressor('RelativeHumidity')
model.add_regressor('Hour')
model.add_regressor('DayOfWeek')
model.add_regressor('Month')
model.add_regressor('IsWeekend')
model.add_regressor('Temp_Humidity_Interaction')

for lag in range(1, 25):
    model.add_regressor(f'Lag_{lag}')

print("--- Fitting Prophet Model ---")
model.fit(df)

# --- 3. Cross-Validation and Evaluation ---
print("\n--- Starting Cross-Validation ---")
# Perform cross-validation with a horizon that covers all our time steps
df_cv = cross_validation(model, initial='365 days', period='180 days', horizon='24 hours', parallel="processes")

# Display aggregated performance metrics from Prophet
df_p = performance_metrics(df_cv)
print("\nCross-validation performance metrics (aggregated by Prophet):")
print(df_p.head())

# Define a robust MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    if np.sum(non_zero_indices) == 0:
        return 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

# Calculate and display metrics for our specific horizons
print("\n--- Performance Metrics for Specific Horizons ---")
# FIX: Calculate the 'horizon' column manually from 'ds' and 'cutoff'
df_cv['horizon'] = df_cv['ds'] - df_cv['cutoff']
df_cv['horizon_hours'] = df_cv['horizon'].dt.total_seconds() / 3600
horizons = [1, 6, 12, 24]

for h in horizons:
    df_h = df_cv[df_cv['horizon_hours'] == h]
    if not df_h.empty:
        mae = mean_absolute_error(df_h['y'], df_h['yhat'])
        mse = mean_squared_error(df_h['y'], df_h['yhat'])
        rmse = np.sqrt(mse)
        r2 = r2_score(df_h['y'], df_h['yhat'])
        mape = mean_absolute_percentage_error(df_h['y'], df_h['yhat'])

        print(f'\nHorizon: {h} hours')
        print(f'  MAE: {mae:.4f}')
        print(f'  MSE: {mse:.4f}')
        print(f'  RMSE: {rmse:.4f}')
        print(f'  R2 Score: {r2:.4f}')
        print(f'  MAPE: {mape:.4f}%')
    else:
        print(f'\nNo data for horizon: {h} hours')


# --- 4. Final Forecast and Plotting ---
print("\n--- Generating Final Forecast and Plots ---")
future = df.drop(columns=['y'])
forecast = model.predict(future)

# Join forecast with actuals for plotting
df.set_index('ds', inplace=True)
forecast.set_index('ds', inplace=True)
aligned_df = df.join(forecast[['yhat']], how='inner')

# Plot a sample of the results
sample_period = 100
plt.figure(figsize=(15, 7))
plt.plot(aligned_df.index[-sample_period:], aligned_df['y'].iloc[-sample_period:], label='Actual', color='b', marker='o')
plt.plot(aligned_df.index[-sample_period:], aligned_df['yhat'].iloc[-sample_period:], label='Predicted', color='r', linestyle='--')
plt.title('Prophet: Sample of Actual vs Predicted Energy Demand')
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Prophet components
print("\n--- Plotting Prophet Components ---")
fig_components = model.plot_components(forecast)
plt.show()
# Out:
# --- Fitting Prophet Model ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/_6scat2i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/m5fh26sa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71439', 'data', 'file=/tmp/tmpqhuo8fwg/_6scat2i.json', 'init=/tmp/tmpqhuo8fwg/m5fh26sa.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modeloo27eawh/prophet_model-20250914052723.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:27:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# --- Starting Cross-Validation ---
# INFO:prophet:Making 17 forecasts with cutoffs between 2016-09-01 00:00:00 and 2024-07-21 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7a373c25a9f0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/lkmv5pvd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/c59hjw6e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/75s52cqe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47978', 'data', 'file=/tmp/tmpqhuo8fwg/lkmv5pvd.json', 'init=/tmp/tmpqhuo8fwg/75s52cqe.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelt_f4bd7m/prophet_model-20250914052758.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/bj7dfkam.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63779', 'data', 'file=/tmp/tmpqhuo8fwg/c59hjw6e.json', 'init=/tmp/tmpqhuo8fwg/bj7dfkam.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_model3ojj9oe8/prophet_model-20250914052759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/rhy_m4p7.json
# 05:28:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/d_2vp1dh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83011', 'data', 'file=/tmp/tmpqhuo8fwg/rhy_m4p7.json', 'init=/tmp/tmpqhuo8fwg/d_2vp1dh.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelb3ut5udq/prophet_model-20250914052806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/rvl506wa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/63dwnv94.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38274', 'data', 'file=/tmp/tmpqhuo8fwg/rvl506wa.json', 'init=/tmp/tmpqhuo8fwg/63dwnv94.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modeltvx3p5sl/prophet_model-20250914052810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/hw4hcg85.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/7eai_cqj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37735', 'data', 'file=/tmp/tmpqhuo8fwg/hw4hcg85.json', 'init=/tmp/tmpqhuo8fwg/7eai_cqj.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelsx39rl4w/prophet_model-20250914052831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/zga3x0fy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/stfxm783.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71414', 'data', 'file=/tmp/tmpqhuo8fwg/zga3x0fy.json', 'init=/tmp/tmpqhuo8fwg/stfxm783.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelvi1mcvg2/prophet_model-20250914052841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/03v_x77t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/8mjax60u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70825', 'data', 'file=/tmp/tmpqhuo8fwg/03v_x77t.json', 'init=/tmp/tmpqhuo8fwg/8mjax60u.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modeltiih3o6t/prophet_model-20250914052857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:29:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/p30b825w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/3tj67b71.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44523', 'data', 'file=/tmp/tmpqhuo8fwg/p30b825w.json', 'init=/tmp/tmpqhuo8fwg/3tj67b71.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelqnrkxh9u/prophet_model-20250914052925.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:29:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:29:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/lk0fw2_g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/hqhxquqx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73586', 'data', 'file=/tmp/tmpqhuo8fwg/lk0fw2_g.json', 'init=/tmp/tmpqhuo8fwg/hqhxquqx.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_model9w7p8ktd/prophet_model-20250914052939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:29:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:30:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/c10y4_o2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/of2_uzpp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72144', 'data', 'file=/tmp/tmpqhuo8fwg/c10y4_o2.json', 'init=/tmp/tmpqhuo8fwg/of2_uzpp.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelbhd0ryg6/prophet_model-20250914053023.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:30:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:30:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/9t1o8dij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/psesa01o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14075', 'data', 'file=/tmp/tmpqhuo8fwg/9t1o8dij.json', 'init=/tmp/tmpqhuo8fwg/psesa01o.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelidbv4dzp/prophet_model-20250914053043.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:30:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:31:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/0ktlyy0l.json
# 05:31:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/vqk5wswe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/q3fn7buc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36898', 'data', 'file=/tmp/tmpqhuo8fwg/0ktlyy0l.json', 'init=/tmp/tmpqhuo8fwg/q3fn7buc.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_model4ofuc2cr/prophet_model-20250914053144.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:31:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/731p7s8d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6973', 'data', 'file=/tmp/tmpqhuo8fwg/vqk5wswe.json', 'init=/tmp/tmpqhuo8fwg/731p7s8d.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelxxrw9ybm/prophet_model-20250914053154.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:31:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:32:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/0aqzz293.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/2o2iqhvj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56863', 'data', 'file=/tmp/tmpqhuo8fwg/0aqzz293.json', 'init=/tmp/tmpqhuo8fwg/2o2iqhvj.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelmvh3rut_/prophet_model-20250914053313.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:33:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:33:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/rqe_c_mw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/uvsvmdon.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34162', 'data', 'file=/tmp/tmpqhuo8fwg/rqe_c_mw.json', 'init=/tmp/tmpqhuo8fwg/uvsvmdon.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelwa1qg9ac/prophet_model-20250914053404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:34:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:34:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/t0zc0q9_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/p_bdt3qq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85806', 'data', 'file=/tmp/tmpqhuo8fwg/t0zc0q9_.json', 'init=/tmp/tmpqhuo8fwg/p_bdt3qq.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_modelhymadj3l/prophet_model-20250914053444.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:34:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:35:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/40rz5hxe.json
# 05:35:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqhuo8fwg/tf0co8h_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44163', 'data', 'file=/tmp/tmpqhuo8fwg/40rz5hxe.json', 'init=/tmp/tmpqhuo8fwg/tf0co8h_.json', 'output', 'file=/tmp/tmpqhuo8fwg/prophet_model9m0nqrcr/prophet_model-20250914053538.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:35:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:36:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Cross-validation performance metrics (aggregated by Prophet):
#           horizon          mse       rmse        mae      mape     mdape  \
# 0 0 days 03:00:00   439.095539  20.954607  15.933662  0.017819  0.015950
# 1 0 days 04:00:00   315.915049  17.773999  13.344424  0.016179  0.011165
# 2 0 days 05:00:00   443.174187  21.051703  15.709055  0.018919  0.014476
# 3 0 days 06:00:00  1017.397783  31.896674  24.428027  0.027585  0.019233
# 4 0 days 07:00:00  2270.185455  47.646463  39.206206  0.042412  0.030057
#
#       smape  coverage
# 0  0.018030  1.000000
# 1  0.016196  1.000000
# 2  0.018844  1.000000
# 3  0.027597  0.973684
# 4  0.042428  0.947368
#
# --- Performance Metrics for Specific Horizons ---
#
# Horizon: 1 hours
#   MAE: 16.6351
#   MSE: 571.1110
#   RMSE: 23.8979
#   R2 Score: 0.9830
#   MAPE: 1.7502%
#
# Horizon: 6 hours
#   MAE: 32.1678
#   MSE: 1579.7107
#   RMSE: 39.7456
#   R2 Score: 0.9150
#   MAPE: 3.5299%
#
# Horizon: 12 hours
#   MAE: 47.0859
#   MSE: 2997.8971
#   RMSE: 54.7531
#   R2 Score: 0.9827
#   MAPE: 4.1459%
#
# Horizon: 24 hours
#   MAE: 20.7198
#   MSE: 639.9425
#   RMSE: 25.2971
#   R2 Score: 0.9845
#   MAPE: 2.1519%
#
# --- Generating Final Forecast and Plots ---
# --- Plotting Prophet Components ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1732639028.py in <cell line: 0>()
#     137 # Plot Prophet components
#     138 print("\n--- Plotting Prophet Components ---")
# --> 139 fig_components = model.plot_components(forecast)
#     140 plt.show()
#     141
#
# /usr/local/lib/python3.12/dist-packages/prophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1933         A matplotlib figure.
#    1934         """
# -> 1935         return plot_components(
#    1936             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1937             weekly_start=weekly_start, yearly_start=yearly_start,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     163     for ax, plot_name in zip(axes, components):
#     164         if plot_name == 'trend':
# --> 165             plot_forecast_component(
#     166                 m=m, fcst=fcst, name='trend', ax=ax, uncertainty=uncertainty,
#     167                 plot_cap=plot_cap,
#
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py in plot_forecast_component(m, fcst, name, ax, uncertainty, plot_cap, figsize)
#     227         fig = plt.figure(facecolor='w', figsize=figsize)
#     228         ax = fig.add_subplot(111)
# --> 229     fcst_t = fcst['ds']
#     230     artists += ax.plot(fcst_t, fcst[name], ls='-', c='#0072B2')
#     231     if 'cap' in fcst and plot_cap:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ds'
