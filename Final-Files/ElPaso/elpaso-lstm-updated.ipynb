# %%
# El Paso LSTM
# Updates from og version:
# Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# Additional Metrics: MAE, MSE, RMSE, R-squared, MAPE for each forecast horizon

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# data loading and feature engineering
# load dataset and replace 'city.xlsx' with the correct path

try:
    df = pd.read_csv('/kaggle/input/elpaso/ElPaso.csv')
except FileNotFoundError:
    print("Error: 'ElPaso.csv' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['D'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['D'].values.reshape(-1, 1)
dates = df['time'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# 2. Sequence Creation for time Series Forecasting
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# 3. Model Training and Evaluation using K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for LSTM Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the LSTM model
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# 4. Display Results
print("\n--- Average Performance Metrics for LSTM Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('LSTM: Predicted vs Actual Energy Demand for Baltimore (1-Hour Horizon)')
plt.xlabel('time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# --- Starting K-Fold Cross-Validation for LSTM Model ---
#
# --- Fold 1/5 ---
# I0000 00:00:1757824998.875576      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1757824998.876291      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757825003.448706      99 service.cc:148] XLA service 0x7f232c0bc2a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1757825003.450188      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1757825003.450210      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1757825003.832571      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   45/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1706
# I0000 00:00:1757825005.342885      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0241 - val_loss: 4.2493e-04
# Epoch 2/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0011 - val_loss: 2.8946e-04
# Epoch 3/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.8481e-04 - val_loss: 1.6792e-04
# Epoch 4/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.8966e-04 - val_loss: 1.2712e-04
# Epoch 5/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4629e-04 - val_loss: 1.0213e-04
# Epoch 6/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.3582e-04 - val_loss: 7.6404e-05
# Epoch 7/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2476e-04 - val_loss: 1.1067e-04
# Epoch 8/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1921e-04 - val_loss: 7.4318e-05
# Epoch 9/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1382e-04 - val_loss: 8.2131e-05
# Epoch 10/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1537e-04 - val_loss: 6.8986e-05
# Epoch 11/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0856e-04 - val_loss: 7.4963e-05
# Epoch 12/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1199e-04 - val_loss: 6.8583e-05
# Epoch 13/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0493e-04 - val_loss: 7.3799e-05
# Epoch 14/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0688e-04 - val_loss: 8.5364e-05
# Epoch 15/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0522e-04 - val_loss: 6.3601e-05
# Epoch 16/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0345e-04 - val_loss: 6.4539e-05
# Epoch 17/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0343e-04 - val_loss: 5.6618e-05
# Epoch 18/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.0009e-04 - val_loss: 6.0173e-05
# Epoch 19/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 9.8994e-05 - val_loss: 5.7579e-05
# Epoch 20/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 9.7197e-05 - val_loss: 5.5166e-05
# Epoch 21/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0097e-04 - val_loss: 7.3400e-05
# Epoch 22/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 9.6308e-05 - val_loss: 7.2172e-05
# Epoch 23/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 9.8866e-05 - val_loss: 6.0899e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 20.
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 2/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0222 - val_loss: 4.8947e-04
# Epoch 2/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0016 - val_loss: 2.9970e-04
# Epoch 3/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 3.8146e-04 - val_loss: 1.9474e-04
# Epoch 4/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.8574e-04 - val_loss: 1.2405e-04
# Epoch 5/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.6540e-04 - val_loss: 1.9204e-04
# Epoch 6/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.5197e-04 - val_loss: 7.8764e-05
# Epoch 7/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2232e-04 - val_loss: 8.1241e-05
# Epoch 8/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2828e-04 - val_loss: 8.6994e-05
# Epoch 9/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2068e-04 - val_loss: 7.2292e-05
# Epoch 10/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.2439e-04 - val_loss: 6.3989e-05
# Epoch 11/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0986e-04 - val_loss: 7.1138e-05
# Epoch 12/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.0809e-04 - val_loss: 7.5552e-05
# Epoch 13/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1563e-04 - val_loss: 5.7906e-05
# Epoch 14/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1128e-04 - val_loss: 7.7959e-05
# Epoch 15/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1306e-04 - val_loss: 6.0529e-05
# Epoch 16/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1049e-04 - val_loss: 5.8724e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 3/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0152 - val_loss: 3.5106e-04
# Epoch 2/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 9.9438e-04 - val_loss: 2.8447e-04
# Epoch 3/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 2.6737e-04 - val_loss: 1.9354e-04
# Epoch 4/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.6737e-04 - val_loss: 1.0337e-04
# Epoch 5/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4957e-04 - val_loss: 1.2821e-04
# Epoch 6/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.3351e-04 - val_loss: 1.0630e-04
# Epoch 7/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.2590e-04 - val_loss: 7.8151e-05
# Epoch 8/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1770e-04 - val_loss: 6.6615e-05
# Epoch 9/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2082e-04 - val_loss: 7.8143e-05
# Epoch 10/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1434e-04 - val_loss: 6.7367e-05
# Epoch 11/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1463e-04 - val_loss: 7.6454e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 4/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0178 - val_loss: 3.5251e-04
# Epoch 2/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0012 - val_loss: 2.7962e-04
# Epoch 3/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 2.9057e-04 - val_loss: 1.5337e-04
# Epoch 4/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.9481e-04 - val_loss: 1.0196e-04
# Epoch 5/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.6399e-04 - val_loss: 1.6110e-04
# Epoch 6/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.5635e-04 - val_loss: 9.0433e-05
# Epoch 7/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.5475e-04 - val_loss: 9.2833e-05
# Epoch 8/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.3471e-04 - val_loss: 8.5251e-05
# Epoch 9/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.2744e-04 - val_loss: 9.4550e-05
# Epoch 10/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.2711e-04 - val_loss: 8.7284e-05
# Epoch 11/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4230e-04 - val_loss: 8.4209e-05
# Epoch 12/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.3240e-04 - val_loss: 1.2155e-04
# Epoch 13/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1327e-04 - val_loss: 7.0176e-05
# Epoch 14/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.2571e-04 - val_loss: 1.0857e-04
# Epoch 15/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1358e-04 - val_loss: 6.3702e-05
# Epoch 16/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.3402e-04 - val_loss: 7.0105e-05
# Epoch 17/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.1650e-04 - val_loss: 7.8020e-05
# Epoch 18/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.2440e-04 - val_loss: 8.6179e-05
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 5/5 ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0213 - val_loss: 3.9541e-04
# Epoch 2/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0011 - val_loss: 3.5041e-04
# Epoch 3/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.7705e-04 - val_loss: 2.5999e-04
# Epoch 4/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.9269e-04 - val_loss: 1.5755e-04
# Epoch 5/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.5384e-04 - val_loss: 1.3303e-04
# Epoch 6/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.4507e-04 - val_loss: 1.0161e-04
# Epoch 7/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4973e-04 - val_loss: 7.7269e-05
# Epoch 8/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.3741e-04 - val_loss: 8.0508e-05
# Epoch 9/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.3052e-04 - val_loss: 1.7207e-04
# Epoch 10/30
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.3017e-04 - val_loss: 1.1549e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Average Performance Metrics for LSTM Model ---
#
# Horizon: 1 hours
#   Average MAE: 69.6788
#   Average MSE: 10765.3048
#   Average RMSE: 101.9033
#   Average R2: 0.8765
#   Average MAPE: 7.3847
#
# Horizon: 6 hours
#   Average MAE: 76.0051
#   Average MSE: 12432.8817
#   Average RMSE: 110.6681
#   Average R2: 0.8584
#   Average MAPE: 7.9864
#
# Horizon: 12 hours
#   Average MAE: 81.7712
#   Average MSE: 14279.8511
#   Average RMSE: 118.6187
#   Average R2: 0.8381
#   Average MAPE: 8.4867
#
# Horizon: 24 hours
#   Average MAE: 89.0802
#   Average MSE: 17219.6905
#   Average RMSE: 130.1118
#   Average R2: 0.8034
#   Average MAPE: 9.1766
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
