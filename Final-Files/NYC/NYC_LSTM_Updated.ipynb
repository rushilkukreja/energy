# %%
# New York City LSTM
# Updates from og version:
# Multi-Horizon Forecasting: Predicts energy demand for 1, 6, 12, and 24 hours ahead.
# Additional Metrics: MAE, MSE, RMSE, R-squared, MAPE for each forecast horizon

#REMOVED TEMP

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# data loading and feature engineering
# load dataset and replace 'city.xlsx' with the correct path

try:
    df = pd.read_excel('New York City.xlsx')
except FileNotFoundError:
    print("Error: 'New York City.xlsx' not found. Please ensure the dataset is in the correct directory.")
    exit()

df.dropna(inplace=True)

# Create time-based features
df['Hour'] = pd.to_datetime(df['Time']).dt.hour
df['DayOfWeek'] = pd.to_datetime(df['Time']).dt.dayofweek
df['Month'] = pd.to_datetime(df['Time']).dt.month
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Create lag features
for lag in range(1, 25):
    df[f'Lag_{lag}'] = df['EnergyDemand'].shift(lag)

# Create rolling window features
df['Temp_RollingMean_24'] = df['Temperature'].rolling(window=24).mean()
df['Temp_RollingStd_24'] = df['Temperature'].rolling(window=24).std()

# Create interaction features
df['Temp_Humidity_Interaction'] = df['Temperature'] * df['RelativeHumidity']

df.dropna(inplace=True)

# Define features and target
features = df[['DewPoint', 'RelativeHumidity', 'Precipitation', 'WindSpeed', 'Pressure',
               'Hour', 'DayOfWeek', 'Month', 'IsWeekend',
               'Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5', 'Lag_6', 'Lag_7', 'Lag_8', 'Lag_9', 'Lag_10',
               'Lag_11', 'Lag_12', 'Lag_13', 'Lag_14', 'Lag_15', 'Lag_16', 'Lag_17', 'Lag_18', 'Lag_19',
               'Lag_20', 'Lag_21', 'Lag_22', 'Lag_23', 'Lag_24',
               'Temp_Humidity_Interaction']].values
energy_demand = df['EnergyDemand'].values.reshape(-1, 1)
dates = df['Time'].values

# Scale features and target
scaler_features = MinMaxScaler()
scaler_energy = MinMaxScaler()
features_normalized = scaler_features.fit_transform(features)
energy_demand_normalized = scaler_energy.fit_transform(energy_demand)

# 2. Sequence Creation for Time Series Forecasting
def create_sequences(data, target, dates, seq_length, horizons):
    """
    Creates sequences of data for time series forecasting.
    """
    sequences = []
    targets = []
    sequence_dates = []
    for i in range(len(data) - seq_length - max(horizons) + 1):
        seq = data[i:i+seq_length]
        target_seq = [target[i + seq_length + h - 1][0] for h in horizons]
        date_seq = dates[i+seq_length]
        sequences.append(seq)
        targets.append(target_seq)
        sequence_dates.append(date_seq)
    return np.array(sequences), np.array(targets), np.array(sequence_dates)

seq_length = 24
horizons = [1, 6, 12, 24]
X, y, dates_seq = create_sequences(features_normalized, energy_demand_normalized, dates, seq_length, horizons)

# 3. Model Training and Evaluation using K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=False)

# Initialize dictionaries to store metrics for each horizon
all_metrics = {h: {'mae': [], 'mse': [], 'rmse': [], 'r2': [], 'mape': []} for h in horizons}

def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculates Mean Absolute Percentage Error.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_indices = y_true != 0
    return np.mean(np.abs((y_true[non_zero_indices] - y_pred[non_zero_indices]) / y_true[non_zero_indices])) * 100

result_df = pd.DataFrame()

print("--- Starting K-Fold Cross-Validation for LSTM Model ---")
for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"\n--- Fold {fold+1}/5 ---")
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    dates_test = dates_seq[test_index]

    # Define the LSTM model
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(seq_length, X.shape[2])),
        Dropout(0.2),
        Dense(len(horizons))
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

    # Use EarlyStopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
        verbose=1
    )

    # Train the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=1)

    # Make predictions and inverse transform them
    predictions_normalized = model.predict(X_test)
    predictions = scaler_energy.inverse_transform(predictions_normalized)
    y_test_original = scaler_energy.inverse_transform(y_test)

    # Calculate and store metrics for each horizon
    for i, h in enumerate(horizons):
        mae = mean_absolute_error(y_test_original[:, i], predictions[:, i])
        mse = mean_squared_error(y_test_original[:, i], predictions[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original[:, i], predictions[:, i])
        mape = mean_absolute_percentage_error(y_test_original[:, i], predictions[:, i])

        all_metrics[h]['mae'].append(mae)
        all_metrics[h]['mse'].append(mse)
        all_metrics[h]['rmse'].append(rmse)
        all_metrics[h]['r2'].append(r2)
        all_metrics[h]['mape'].append(mape)

    # Store results for plotting
    fold_results = pd.DataFrame({'Date': dates_test})
    for i, h in enumerate(horizons):
        fold_results[f'Actual_{h}h'] = y_test_original[:, i]
        fold_results[f'Predicted_{h}h'] = predictions[:, i]

    result_df = pd.concat([result_df, fold_results], ignore_index=True)

# 4. Display Results
print("\n--- Average Performance Metrics for LSTM Model ---")
for h in horizons:
    print(f'\nHorizon: {h} hours')
    for metric_name, values in all_metrics[h].items():
        print(f'  Average {metric_name.upper()}: {np.mean(values):.4f}')

# Plot results for the 1-hour horizon as an example
print("\n--- Plotting Results for 1-Hour Horizon (First 100 Points) ---")
plt.figure(figsize=(15, 7))
plt.plot(result_df['Date'][:100], result_df['Actual_1h'][:100], label='Actual 1-hour ahead', marker='o', linestyle='-')
plt.plot(result_df['Date'][:100], result_df['Predicted_1h'][:100], label='Predicted 1-hour ahead', marker='x', linestyle='--')
plt.title('LSTM: Predicted vs Actual Energy Demand for New York City (1-Hour Horizon)')
plt.xlabel('Time')
plt.ylabel('Energy Demand')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# --- Starting K-Fold Cross-Validation for LSTM Model ---
#
# --- Fold 1/5 ---
# /Users/rushilkukreja/Downloads/mahabir/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0090 - val_loss: 0.0011
# Epoch 2/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0032 - val_loss: 9.2625e-04
# Epoch 3/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0023 - val_loss: 8.3976e-04
# Epoch 4/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020 - val_loss: 8.3657e-04
# Epoch 5/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 8.1291e-04
# Epoch 6/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 6.1407e-04
# Epoch 7/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0016 - val_loss: 6.4551e-04
# Epoch 8/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 5.9810e-04
# Epoch 9/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0015 - val_loss: 6.1727e-04
# Epoch 10/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0015 - val_loss: 5.2890e-04
# Epoch 11/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0015 - val_loss: 5.2709e-04
# Epoch 12/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0015 - val_loss: 5.0868e-04
# Epoch 13/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0015 - val_loss: 5.5251e-04
# Epoch 14/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0014 - val_loss: 5.1867e-04
# Epoch 15/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0014 - val_loss: 5.9038e-04
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Fold 2/5 ---
# Epoch 1/30
# /Users/rushilkukreja/Downloads/mahabir/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0087 - val_loss: 0.0011
# Epoch 2/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0032 - val_loss: 8.5044e-04
# Epoch 3/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0023 - val_loss: 8.3316e-04
# Epoch 4/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0021 - val_loss: 7.8084e-04
# Epoch 5/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0019 - val_loss: 5.4879e-04
# Epoch 6/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0018 - val_loss: 5.4504e-04
# Epoch 7/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0017 - val_loss: 5.6024e-04
# Epoch 8/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 4.9568e-04
# Epoch 9/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0016 - val_loss: 4.5448e-04
# Epoch 10/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 4.5916e-04
# Epoch 11/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 4.5578e-04
# Epoch 12/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0016 - val_loss: 4.9729e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Fold 3/5 ---
# Epoch 1/30
# /Users/rushilkukreja/Downloads/mahabir/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0095 - val_loss: 0.0013
# Epoch 2/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0034 - val_loss: 8.8770e-04
# Epoch 3/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0025 - val_loss: 8.9840e-04
# Epoch 4/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 5/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 6.5913e-04
# Epoch 6/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 6.2322e-04
# Epoch 7/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0018 - val_loss: 5.1042e-04
# Epoch 8/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 6.4504e-04
# Epoch 9/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017 - val_loss: 5.6215e-04
# Epoch 10/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 5.0231e-04
# Epoch 11/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 5.3311e-04
# Epoch 12/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0016 - val_loss: 4.7807e-04
# Epoch 13/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0015 - val_loss: 4.8892e-04
# Epoch 14/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0015 - val_loss: 6.4297e-04
# Epoch 15/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0015 - val_loss: 5.3730e-04
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Fold 4/5 ---
# Epoch 1/30
# /Users/rushilkukreja/Downloads/mahabir/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0125 - val_loss: 0.0015
# Epoch 2/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 3/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 4/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0027 - val_loss: 8.8082e-04
# Epoch 5/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0024 - val_loss: 7.0790e-04
# Epoch 6/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0022 - val_loss: 7.6105e-04
# Epoch 7/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.0022 - val_loss: 7.0851e-04
# Epoch 8/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0021 - val_loss: 6.2589e-04
# Epoch 9/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0021 - val_loss: 7.6099e-04
# Epoch 10/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0020 - val_loss: 6.5846e-04
# Epoch 11/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0020 - val_loss: 5.5102e-04
# Epoch 12/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0020 - val_loss: 6.2150e-04
# Epoch 13/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 5.6094e-04
# Epoch 14/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0019 - val_loss: 5.8004e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# --- Fold 5/5 ---
# /Users/rushilkukreja/Downloads/mahabir/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.0113 - val_loss: 0.0013
# Epoch 2/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0039 - val_loss: 9.4687e-04
# Epoch 3/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0027 - val_loss: 8.5142e-04
# Epoch 4/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0024 - val_loss: 7.4130e-04
# Epoch 5/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0022 - val_loss: 7.2108e-04
# Epoch 6/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0021 - val_loss: 6.2532e-04
# Epoch 7/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0020 - val_loss: 6.1620e-04
# Epoch 8/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0020 - val_loss: 6.0987e-04
# Epoch 9/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0020 - val_loss: 5.2206e-04
# Epoch 10/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0019 - val_loss: 5.9231e-04
# Epoch 11/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0019 - val_loss: 5.6974e-04
# Epoch 12/30
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0018 - val_loss: 5.2538e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Average Performance Metrics for LSTM Model ---
#
# Horizon: 1 hours
#   Average MAE: 158.4971
#   Average MSE: 45486.2243
#   Average RMSE: 208.8116
#   Average R2: 0.9677
#   Average MAPE: 2.8190
#
# Horizon: 6 hours
#   Average MAE: 227.8100
#   Average MSE: 101044.1728
#   Average RMSE: 309.7714
#   Average R2: 0.9296
#   Average MAPE: 3.9662
#
# Horizon: 12 hours
#   Average MAE: 300.4532
#   Average MSE: 175351.2818
#   Average RMSE: 410.1478
#   Average R2: 0.8768
#   Average MAPE: 5.2054
#
# Horizon: 24 hours
#   Average MAE: 357.7402
#   Average MSE: 247874.9332
#   Average RMSE: 489.7387
#   Average R2: 0.8237
#   Average MAPE: 6.2788
#
# --- Plotting Results for 1-Hour Horizon (First 100 Points) ---
