# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_csv('../City-Specific Data/San Diego.csv')
msno.matrix(df)
plt.title("Missing Data Visualization for San Diego", fontsize=14)
plt.show()
