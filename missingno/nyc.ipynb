# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_excel('../City-Specific Data/New York City.xlsx')
msno.matrix(df)
plt.title("Missing Data Visualization for New York City", fontsize=14)
plt.show()
