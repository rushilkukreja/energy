# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_excel('../New Runs/ElPasoNew.xlsx')
msno.matrix(df)
plt.title("Missing Data Visualization for El Paso", fontsize=14)
plt.show()
