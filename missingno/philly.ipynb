# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_excel('../City-Specific Data/Philadelphia.xlsx')
msno.matrix(df)
plt.title("Missing Data Visualization for Philadelphia", fontsize=14)
plt.show()
