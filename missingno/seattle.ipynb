# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_excel('../New Runs/SeattleNew.xlsx')
msno.matrix(df)
plt.title("Missing Data Visualization for Seattle", fontsize=14)
plt.show()
