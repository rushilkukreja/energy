# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_excel('../City-Specific Data/San Antonio.xlsx')
msno.matrix(df)
plt.title("Missing Data Visualization for San Antonio", fontsize=14)
plt.show()
