# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
df = pd.read_csv('../City-Specific Data/Omaha.csv')
msno.matrix(df)
plt.title("Missing Data Visualization for Omaha", fontsize=14)
plt.show()
